# %%
using HDF5
using PyPlot

# %%
ENV["PYTHON"] = "path/to/conda/envs/julia-py/python"

# %%
filename = "data/2025-07-24_0003_TwoDGas_0.h5";

# %%
OD = []
imgs_atoms, imgs_bkg, imgs_dark = [], [], []
h5open(filename, "r") do file
    img_atoms = convert(Matrix{Int16}, read(file["images/Horizontal_Axis_Camera/in_situ_absorption/atoms"]))
    img_bkg = convert(Matrix{Int16}, read(file["images/Horizontal_Axis_Camera/in_situ_absorption/background"]))
    img_dark = convert(Matrix{Int16}, read(file["images/Horizontal_Axis_Camera/in_situ_absorption/dark"]))

    # OD = log10((img_atoms-img_bkg)/(img_bkg-img_dark))

    # push!(OD, (img_atoms-img_bkg)/(img_bkg-img_dark))
    # print(typeof(img_atoms))
    # imshow(img_atoms)
    push!(imgs_atoms, img_atoms), push!(imgs_bkg, img_bkg), push!(imgs_dark, img_dark)
end

# pygui(false); gcf()
# pygui(true); show()
# Out:
# (Any[Int16[206 200 … 168 153; 187 186 … 169 180; … ; 261 232 … 187 192; 246 257 … 222 217]], Any[Int16[214 202 … 162 157; 195 190 … 171 170; … ; 249 239 … 188 204; 235 251 … 218 223]], Any[Int16[50 50 … 50 51; 50 50 … 50 51; … ; 50 50 … 50 50; 53 51 … 51 50]])

# %%
maximum(imgs_atoms[1])
# Out:
# 374

# %%
imshow(imgs_atoms[1])
pygui(true); show()
# Out:
# PyError ($(Expr(:escape, :(ccall(#= C:\Users\Joschka\.julia\packages\PyCall\1gn3u\src\pyfncall.jl:43 =# @pysym(:PyObject_Call), PyPtr, (PyPtr, PyPtr, PyPtr), o, pyargsptr, kw))))) <class 'AttributeError'>
#
# AttributeError("type object 'FigureManagerBase' has no attribute '_owns_mainloop'")
#
#   File "c:\users\joschka\appdata\local\programs\python\python313\Lib\site-packages\matplotlib\pyplot.py", line 614, in show
#
#     return _get_backend_mod().show(*args, **kwargs)
#
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^
#
#   File "c:\users\joschka\appdata\local\programs\python\python313\Lib\site-packages\matplotlib\backend_bases.py", line 3550, in show
#
#     cls.mainloop()
#
#     ~~~~~~~~~~~~^^
#
#   File "c:\users\joschka\appdata\local\programs\python\python313\Lib\site-packages\matplotlib\backends\_backend_tk.py", line 568, in start_main_loop
#
#     if manager_class._owns_mainloop:
#
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
#
#
#
# Stacktrace:
#
# ...
