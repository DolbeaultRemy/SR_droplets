# %%
import PhysicalConstants.CODATA2018: c_0
using QuantumCumulants
using CollectiveSpins
using Symbolics
using JLD2
using Unitful

# %% [markdown]
# # System

# %%
# Nbr of particles
N = 2

# Normalisation parameters
λ = 421e-9
γ = 32.7e6 # In Hz

# Physical values
ω0 = (2π*ustrip(c_0)/λ)
ωl = ω0
kl = [ustrip(c_0)/ωl, 0, 0] # Laser along x
Ω_RO = 1e7 # Taken from Barbut arXiv:2412.02541v1

# Position of atoms
Lx, Ly, Lz = [1, 1, 1] * 1e-6
r0 = [[rand(Float64)*Lx, rand(Float64)*Ly, rand(Float64)*Lz] for i in 1:N]

# Save the atoms position for comparison with QuantumOptics
@save "r0.jdl2" r0

# Normalization
ω0 = ω0 / γ
ωl = ωl / γ
kl = kl * λ
r0 = r0 / λ
Ω_RO = Ω_RO / γ

# Compute the Ω and Γ matrices of the electric dipole-dipole interaction using CollectiveSpins
e = [0, 0, 1.] # Quantization axis along z
system = SpinCollection(r0, e, gammas=1.)
Ω_CS = interaction.OmegaMatrix(system)
Γ_CS = interaction.GammaMatrix(system)

# Integration parameter
tstep = 0.1
T = [0:tstep:10;]; # Normalised time

# %% [markdown]
# # Derivation of the symbolic MPC equations

# %%
@cnumbers Nsymb ΩROs

h = NLevelSpace(Symbol(:atom),2)

exp_RO(i) = IndexedVariable(:expRO, i)
conj_exp_RO(i) = IndexedVariable(:conjexpRO, i)
Γ(i,j) = IndexedVariable(:Γ,i,j)
Ω(i,j) = IndexedVariable(:Ω,i,j;identical=false)

i = Index(h,:i,Nsymb,h)
j = Index(h,:j,Nsymb,h)
k = Index(h,:k,Nsymb,h)

σ(x,y,z) = IndexedOperator(Transition(h,:σ,x,y),z)

H_RO = ΩROs * ∑(exp_RO(i)*σ(2,1,i) + conj_exp_RO(i)*σ(1,2,i), i)
H_elec = Σ(Ω(i,j)*σ(2,1,i)*σ(1,2,j), j, i)

H = Symbolics.simplify(H_RO + H_elec)

J = [σ(1,2,i)] # σ-, jump operators for the Lindbladian
rates = [Γ(i,j)]

ops = [σ(2, 2, k), σ(2, 1, k)]; # n_up/σ+

# %%
H
# Out:
# (Σ(j=1:Nsymb)(j≠i)Σ(i=1:Nsymb)(i≠j)Ωij*(σ21i*σ12j)+Σ(i=1:Nsymb)expROi*ΩROs*(σ21i)+Σ(i=1:Nsymb)conjexpROi*ΩROs*(σ12i))

# %%
eqs = meanfield(ops,H,J;rates=rates,order=2)
complete!(eqs)
# Out:
# ∂ₜ(⟨σ22k⟩) = -0.5(var"∑(i=1:Nsymb)(i≠k)⟨σ21i*σ12k⟩*Γik" + var"∑(j=1:Nsymb)(j≠i,k)⟨σ12j*σ21k⟩*Γkj") + (0 + 1im)*var"∑(i=1:Nsymb)(i≠k)⟨σ21i*σ12k⟩*Ωik" + (0 - 1im)*var"∑(j=1:Nsymb)(j≠k)⟨σ12j*σ21k⟩*Ωkj" - ⟨σ22k⟩*Γkk + (0 + 1im)*conjexpROk*⟨σ12k⟩*ΩROs + (0 - 1im)*expROk*⟨σ21k⟩*ΩROs
# ∂ₜ(⟨σ21k⟩) = var"∑(i=1:Nsymb)(i≠k)⟨σ21i*σ22k⟩*Γik" + (0 - 2im)*var"∑(i=1:Nsymb)(i≠k)⟨σ21i*σ22k⟩*Ωik" - 0.5var"∑(i=1:Nsymb)(i≠k)⟨σ21i⟩*Γik" + (0 + 1im)*var"∑(i=1:Nsymb)(i≠k)⟨σ21i⟩*Ωik" + (0 + 1im)*conjexpROk*ΩROs - 0.5⟨σ21k⟩*Γkk + (0 - 2im)*conjexpROk*⟨σ22k⟩*ΩROs
# ∂ₜ(⟨σ12k*σ21l⟩) = var"∑(i=1:Nsymb)(i≠k,l)⟨σ12k*σ22l⟩*⟨σ21i⟩*Γil" + (0 - 2im)*(var"∑(i=1:Nsymb)(i≠k,l)⟨σ12k*σ22l⟩*⟨σ21i⟩*Ωil" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ12k⟩*⟨σ21i*σ22l⟩*Ωil" - 2var"∑(i=1:Nsymb)(i≠k,l)⟨σ12k⟩*⟨σ22l⟩*⟨σ21i⟩*Ωil" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ22l⟩*⟨σ21i*σ12k⟩*Ωil") + var"∑(i=1:Nsymb)(i≠k,l)⟨σ12k⟩*⟨σ21i*σ22l⟩*Γil" - 2var"∑(i=1:Nsymb)(i≠k,l)⟨σ12k⟩*⟨σ22l⟩*⟨σ21i⟩*Γil" - 0.5(var"∑(i=1:Nsymb)(i≠k,l)⟨σ21i*σ12k⟩*Γil" + var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ12j*σ21l⟩*Γkj") + (0 + 1im)*var"∑(i=1:Nsymb)(i≠k,l)⟨σ21i*σ12k⟩*Ωil" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ22l⟩*⟨σ21i*σ12k⟩*Γil" + var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ12j⟩*⟨σ22k*σ21l⟩*Γkj" + var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ21l⟩*⟨σ12j*σ22k⟩*Γkj" - 2var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ21l⟩*⟨σ22k⟩*⟨σ12j⟩*Γkj" + var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ22k⟩*⟨σ12j*σ21l⟩*Γkj" + (0 - 1im)*var"∑(j=1:Nsymb)(j≠k,l)⟨σ12j*σ21l⟩*Ωkj" + (0 + 2im)*(var"∑(j=1:Nsymb)(j≠k,l)⟨σ12j⟩*⟨σ22k*σ21l⟩*Ωkj" + var"∑(j=1:Nsymb)(j≠k,l)⟨σ21l⟩*⟨σ12j*σ22k⟩*Ωkj" - 2var"∑(j=1:Nsymb)(j≠k,l)⟨σ21l⟩*⟨σ22k⟩*⟨σ12j⟩*Ωkj" + var"∑(j=1:Nsymb)(j≠k,l)⟨σ22k⟩*⟨σ12j*σ21l⟩*Ωkj") - 0.5var"(k≠l)⟨σ12k*σ21l⟩"*Γkk - 0.5var"(k≠l)⟨σ12k*σ21l⟩"*Γll + 2.0var"(k≠l)⟨σ22k*σ22l⟩"*Γkl - 0.5var"(k≠l)⟨σ22k⟩"*Γkl + (0 + 1im)*var"(k≠l)⟨σ22k⟩"*Ωkl - 0.5var"(k≠l)⟨σ22l⟩"*Γkl + (0 - 1im)*var"(k≠l)⟨σ22l⟩"*Ωkl + (0 - 2im)*var"(k≠l)⟨σ12k*σ22l⟩"*conjexpROl*ΩROs + (0 + 1im)*var"(k≠l)⟨σ12k⟩"*conjexpROl*ΩROs + (0 - 1im)*var"(k≠l)⟨σ21l⟩"*expROk*ΩROs + (0 + 2im)*var"(k≠l)⟨σ22k*σ21l⟩"*expROk*ΩROs
# ∂ₜ(⟨σ22k*σ21l⟩) = -0.5(var"∑(i=1:Nsymb)(i≠k,l)⟨σ12k*σ21l⟩*⟨σ21i⟩*Γik" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ12k⟩*⟨σ21i*σ21l⟩*Γik" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ21i*σ22k⟩*Γil" - 2var"∑(i=1:Nsymb)(i≠k,l)⟨σ21l⟩*⟨σ12k⟩*⟨σ21i⟩*Γik" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ21l⟩*⟨σ21i*σ12k⟩*Γik" + var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ12j⟩*⟨σ21k*σ21l⟩*Γkj" + var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ21k⟩*⟨σ12j*σ21l⟩*Γkj" + var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ21l⟩*⟨σ12j*σ21k⟩*Γkj" - 2var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ21l⟩*⟨σ21k⟩*⟨σ12j⟩*Γkj") + (0 + 1im)*(var"∑(i=1:Nsymb)(i≠k,l)⟨σ12k*σ21l⟩*⟨σ21i⟩*Ωik" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ12k⟩*⟨σ21i*σ21l⟩*Ωik" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ21i*σ22k⟩*Ωil" - 2var"∑(i=1:Nsymb)(i≠k,l)⟨σ21l⟩*⟨σ12k⟩*⟨σ21i⟩*Ωik" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ21l⟩*⟨σ21i*σ12k⟩*Ωik") + var"∑(i=1:Nsymb)(i≠k,l)⟨σ22k*σ22l⟩*⟨σ21i⟩*Γil" + (0 - 2im)*(var"∑(i=1:Nsymb)(i≠k,l)⟨σ22k*σ22l⟩*⟨σ21i⟩*Ωil" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ22k⟩*⟨σ21i*σ22l⟩*Ωil" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ22l⟩*⟨σ21i*σ22k⟩*Ωil" - 2var"∑(i=1:Nsymb)(i≠k,l)⟨σ22l⟩*⟨σ22k⟩*⟨σ21i⟩*Ωil") + var"∑(i=1:Nsymb)(i≠k,l)⟨σ22k⟩*⟨σ21i*σ22l⟩*Γil" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ22l⟩*⟨σ21i*σ22k⟩*Γil" - 2var"∑(i=1:Nsymb)(i≠k,l)⟨σ22l⟩*⟨σ22k⟩*⟨σ21i⟩*Γil" + (0 - 1im)*(var"∑(j=1:Nsymb)(j≠k,l)⟨σ12j⟩*⟨σ21k*σ21l⟩*Ωkj" + var"∑(j=1:Nsymb)(j≠k,l)⟨σ21k⟩*⟨σ12j*σ21l⟩*Ωkj" + var"∑(j=1:Nsymb)(j≠k,l)⟨σ21l⟩*⟨σ12j*σ21k⟩*Ωkj" - 2var"∑(j=1:Nsymb)(j≠k,l)⟨σ21l⟩*⟨σ21k⟩*⟨σ12j⟩*Ωkj") - 0.5var"(k≠l)⟨σ21k*σ22l⟩"*Γkl + (0 - 1im)*var"(k≠l)⟨σ21k*σ22l⟩"*Ωkl - var"(k≠l)⟨σ22k*σ21l⟩"*Γkk - 0.5var"(k≠l)⟨σ22k*σ21l⟩"*Γll + (0 + 1im)*var"(k≠l)⟨σ12k*σ21l⟩"*conjexpROk*ΩROs + (0 - 1im)*var"(k≠l)⟨σ21k*σ21l⟩"*expROk*ΩROs + (0 - 2im)*var"(k≠l)⟨σ22k*σ22l⟩"*conjexpROl*ΩROs + (0 + 1im)*var"(k≠l)⟨σ22k⟩"*conjexpROl*ΩROs
# ∂ₜ(⟨σ12k*σ22l⟩) = -0.5(var"∑(i=1:Nsymb)(i≠k,l)⟨σ12k*σ12l⟩*⟨σ21i⟩*Γil" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ12k⟩*⟨σ21i*σ12l⟩*Γil" - 2var"∑(i=1:Nsymb)(i≠k,l)⟨σ12l⟩*⟨σ12k⟩*⟨σ21i⟩*Γil" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ12l⟩*⟨σ21i*σ12k⟩*Γil" + var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ12j*σ22l⟩*Γkj" + var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ12k*σ21l⟩*⟨σ12j⟩*Γlj" + var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ12k⟩*⟨σ12j*σ21l⟩*Γlj" + var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ21l⟩*⟨σ12j*σ12k⟩*Γlj" - 2var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ21l⟩*⟨σ12k⟩*⟨σ12j⟩*Γlj") + (0 + 1im)*(var"∑(i=1:Nsymb)(i≠k,l)⟨σ12k*σ12l⟩*⟨σ21i⟩*Ωil" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ12k⟩*⟨σ21i*σ12l⟩*Ωil" - 2var"∑(i=1:Nsymb)(i≠k,l)⟨σ12l⟩*⟨σ12k⟩*⟨σ21i⟩*Ωil" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ12l⟩*⟨σ21i*σ12k⟩*Ωil") + var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ22k*σ22l⟩*⟨σ12j⟩*Γkj" + var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ22k⟩*⟨σ12j*σ22l⟩*Γkj" + var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ22l⟩*⟨σ12j*σ22k⟩*Γkj" - 2var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ22l⟩*⟨σ22k⟩*⟨σ12j⟩*Γkj" + (0 - 1im)*(var"∑(j=1:Nsymb)(j≠k,l)⟨σ12j*σ22l⟩*Ωkj" + var"∑(j=1:Nsymb)(j≠k,l)⟨σ12k*σ21l⟩*⟨σ12j⟩*Ωlj" + var"∑(j=1:Nsymb)(j≠k,l)⟨σ12k⟩*⟨σ12j*σ21l⟩*Ωlj" + var"∑(j=1:Nsymb)(j≠k,l)⟨σ21l⟩*⟨σ12j*σ12k⟩*Ωlj" - 2var"∑(j=1:Nsymb)(j≠k,l)⟨σ21l⟩*⟨σ12k⟩*⟨σ12j⟩*Ωlj") + (0 + 2im)*(var"∑(j=1:Nsymb)(j≠k,l)⟨σ22k*σ22l⟩*⟨σ12j⟩*Ωkj" + var"∑(j=1:Nsymb)(j≠k,l)⟨σ22k⟩*⟨σ12j*σ22l⟩*Ωkj" + var"∑(j=1:Nsymb)(j≠k,l)⟨σ22l⟩*⟨σ12j*σ22k⟩*Ωkj" - 2var"∑(j=1:Nsymb)(j≠k,l)⟨σ22l⟩*⟨σ22k⟩*⟨σ12j⟩*Ωkj") - 0.5var"(k≠l)⟨σ12k*σ22l⟩"*Γkk - var"(k≠l)⟨σ12k*σ22l⟩"*Γll - 0.5var"(k≠l)⟨σ22k*σ12l⟩"*Γkl + (0 + 1im)*var"(k≠l)⟨σ22k*σ12l⟩"*Ωkl + (0 + 1im)*var"(k≠l)⟨σ12k*σ12l⟩"*conjexpROl*ΩROs + (0 - 1im)*var"(k≠l)⟨σ12k*σ21l⟩"*expROl*ΩROs + (0 + 2im)*var"(k≠l)⟨σ22k*σ22l⟩"*expROk*ΩROs + (0 - 1im)*var"(k≠l)⟨σ22l⟩"*expROk*ΩROs
# ∂ₜ(⟨σ22k*σ22l⟩) = -0.5(var"∑(i=1:Nsymb)(i≠k,l)⟨σ12k*σ22l⟩*⟨σ21i⟩*Γik" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ12k⟩*⟨σ21i*σ22l⟩*Γik" - 2var"∑(i=1:Nsymb)(i≠k,l)⟨σ12k⟩*⟨σ22l⟩*⟨σ21i⟩*Γik" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ12l⟩*⟨σ21i*σ22k⟩*Γil" - 2var"∑(i=1:Nsymb)(i≠k,l)⟨σ12l⟩*⟨σ22k⟩*⟨σ21i⟩*Γil" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ21i*σ12l⟩*⟨σ22k⟩*Γil" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ22k*σ12l⟩*⟨σ21i⟩*Γil" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ22l⟩*⟨σ21i*σ12k⟩*Γik" + var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ12j⟩*⟨σ22k*σ21l⟩*Γlj" + var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ21k*σ22l⟩*⟨σ12j⟩*Γkj" + var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ21k⟩*⟨σ12j*σ22l⟩*Γkj" + var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ21l⟩*⟨σ12j*σ22k⟩*Γlj" - 2var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ21l⟩*⟨σ22k⟩*⟨σ12j⟩*Γlj" + var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ22k⟩*⟨σ12j*σ21l⟩*Γlj" + var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ22l⟩*⟨σ12j*σ21k⟩*Γkj" - 2var"∑(j=1:Nsymb)(j≠i,k,l)⟨σ22l⟩*⟨σ21k⟩*⟨σ12j⟩*Γkj") + (0 + 1im)*(var"∑(i=1:Nsymb)(i≠k,l)⟨σ12k*σ22l⟩*⟨σ21i⟩*Ωik" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ12k⟩*⟨σ21i*σ22l⟩*Ωik" - 2var"∑(i=1:Nsymb)(i≠k,l)⟨σ12k⟩*⟨σ22l⟩*⟨σ21i⟩*Ωik" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ12l⟩*⟨σ21i*σ22k⟩*Ωil" - 2var"∑(i=1:Nsymb)(i≠k,l)⟨σ12l⟩*⟨σ22k⟩*⟨σ21i⟩*Ωil" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ21i*σ12l⟩*⟨σ22k⟩*Ωil" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ22k*σ12l⟩*⟨σ21i⟩*Ωil" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ22l⟩*⟨σ21i*σ12k⟩*Ωik") + (0 - 1im)*(var"∑(j=1:Nsymb)(j≠k,l)⟨σ12j⟩*⟨σ22k*σ21l⟩*Ωlj" + var"∑(j=1:Nsymb)(j≠k,l)⟨σ21k*σ22l⟩*⟨σ12j⟩*Ωkj" + var"∑(j=1:Nsymb)(j≠k,l)⟨σ21k⟩*⟨σ12j*σ22l⟩*Ωkj" + var"∑(j=1:Nsymb)(j≠k,l)⟨σ21l⟩*⟨σ12j*σ22k⟩*Ωlj" - 2var"∑(j=1:Nsymb)(j≠k,l)⟨σ21l⟩*⟨σ22k⟩*⟨σ12j⟩*Ωlj" + var"∑(j=1:Nsymb)(j≠k,l)⟨σ22k⟩*⟨σ12j*σ21l⟩*Ωlj" + var"∑(j=1:Nsymb)(j≠k,l)⟨σ22l⟩*⟨σ12j*σ21k⟩*Ωkj" - 2var"∑(j=1:Nsymb)(j≠k,l)⟨σ22l⟩*⟨σ21k⟩*⟨σ12j⟩*Ωkj") + var"(k≠l)⟨σ22k*σ22l⟩"*(-Γkk - Γll) + (0 + 1im)*var"(k≠l)⟨σ12k*σ22l⟩"*conjexpROk*ΩROs + (0 - 1im)*var"(k≠l)⟨σ21k*σ22l⟩"*expROk*ΩROs + (0 + 1im)*var"(k≠l)⟨σ22k*σ12l⟩"*conjexpROl*ΩROs + (0 - 1im)*var"(k≠l)⟨σ22k*σ21l⟩"*expROl*ΩROs
# ∂ₜ(⟨σ21k*σ21l⟩) = -0.5(var"∑(i=1:Nsymb)(i≠k,l)⟨σ21i*σ21k⟩*Γil" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ21i*σ21l⟩*Γik") + (0 + 1im)*(var"∑(i=1:Nsymb)(i≠k,l)⟨σ21i*σ21k⟩*Ωil" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ21i*σ21l⟩*Ωik") + var"∑(i=1:Nsymb)(i≠k,l)⟨σ21i*σ21l⟩*⟨σ22k⟩*Γik" + (0 - 2im)*(var"∑(i=1:Nsymb)(i≠k,l)⟨σ21i*σ21l⟩*⟨σ22k⟩*Ωik" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ21k*σ22l⟩*⟨σ21i⟩*Ωil" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ21k⟩*⟨σ21i*σ22l⟩*Ωil" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ21l⟩*⟨σ21i*σ22k⟩*Ωik" - 2var"∑(i=1:Nsymb)(i≠k,l)⟨σ21l⟩*⟨σ22k⟩*⟨σ21i⟩*Ωik" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ22k*σ21l⟩*⟨σ21i⟩*Ωik" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ22l⟩*⟨σ21i*σ21k⟩*Ωil" - 2var"∑(i=1:Nsymb)(i≠k,l)⟨σ22l⟩*⟨σ21k⟩*⟨σ21i⟩*Ωil") + var"∑(i=1:Nsymb)(i≠k,l)⟨σ21k*σ22l⟩*⟨σ21i⟩*Γil" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ21k⟩*⟨σ21i*σ22l⟩*Γil" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ21l⟩*⟨σ21i*σ22k⟩*Γik" - 2var"∑(i=1:Nsymb)(i≠k,l)⟨σ21l⟩*⟨σ22k⟩*⟨σ21i⟩*Γik" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ22k*σ21l⟩*⟨σ21i⟩*Γik" + var"∑(i=1:Nsymb)(i≠k,l)⟨σ22l⟩*⟨σ21i*σ21k⟩*Γil" - 2var"∑(i=1:Nsymb)(i≠k,l)⟨σ22l⟩*⟨σ21k⟩*⟨σ21i⟩*Γil" - 0.5var"(k≠l)⟨σ21k*σ21l⟩"*(Γkk + Γll) + (0 - 2im)*var"(k≠l)⟨σ21k*σ22l⟩"*conjexpROl*ΩROs + (0 + 1im)*var"(k≠l)⟨σ21k⟩"*conjexpROl*ΩROs + (0 + 1im)*var"(k≠l)⟨σ21l⟩"*conjexpROk*ΩROs + (0 - 2im)*var"(k≠l)⟨σ22k*σ21l⟩"*conjexpROk*ΩROs

# %% [markdown]
# ### Evaluate equations

# %%
eqs_eval = evaluate(eqs; limits=(Nsymb=>N))
# Out:
# ∂ₜ(⟨σ221⟩) = -⟨σ221⟩*var"Γ_{1,1}" - 0.5(⟨⟨σ211*σ122⟩⟩*var"Γ_{2,1}" + ⟨σ211*σ122⟩*var"Γ_{1,2}") + (0 + 1im)*⟨⟨σ211*σ122⟩⟩*var"Ω_{2,1}" + (0 - 1im)*⟨σ211*σ122⟩*var"Ω_{1,2}" + (0 + 1im)*conjexpRO_1*⟨⟨σ211⟩⟩*ΩROs + (0 - 1im)*expRO_1*⟨σ211⟩*ΩROs
# ∂ₜ(⟨σ222⟩) = -0.5(⟨⟨σ211*σ122⟩⟩*var"Γ_{2,1}" + ⟨σ211*σ122⟩*var"Γ_{1,2}") + (0 - 1im)*⟨⟨σ211*σ122⟩⟩*var"Ω_{2,1}" + (0 + 1im)*⟨σ211*σ122⟩*var"Ω_{1,2}" - ⟨σ222⟩*var"Γ_{2,2}" + (0 + 1im)*conjexpRO_2*⟨⟨σ212⟩⟩*ΩROs + (0 - 1im)*expRO_2*⟨σ212⟩*ΩROs
# ∂ₜ(⟨σ211⟩) = (0 + 1im)*conjexpRO_1*ΩROs + ⟨σ221*σ212⟩*var"Γ_{2,1}" + (0 - 2im)*⟨σ221*σ212⟩*var"Ω_{2,1}" - 0.5⟨σ212⟩*var"Γ_{2,1}" + (0 + 1im)*⟨σ212⟩*var"Ω_{2,1}" - 0.5⟨σ211⟩*var"Γ_{1,1}" + (0 - 2im)*conjexpRO_1*⟨σ221⟩*ΩROs
# ∂ₜ(⟨σ212⟩) = (0 + 1im)*conjexpRO_2*ΩROs - 0.5⟨σ212⟩*var"Γ_{2,2}" - 0.5⟨σ211⟩*var"Γ_{1,2}" + (0 + 1im)*⟨σ211⟩*var"Ω_{1,2}" + ⟨σ211*σ222⟩*var"Γ_{1,2}" + (0 - 2im)*⟨σ211*σ222⟩*var"Ω_{1,2}" + (0 - 2im)*conjexpRO_2*⟨σ222⟩*ΩROs
# ∂ₜ(⟨σ211*σ122⟩) = -0.5⟨σ221⟩*var"Γ_{2,1}" + (0 - 1im)*⟨σ221⟩*var"Ω_{2,1}" + 2.0⟨σ221*σ222⟩*var"Γ_{2,1}" - 0.5⟨σ211*σ122⟩*var"Γ_{1,1}" - 0.5⟨σ211*σ122⟩*var"Γ_{2,2}" - 0.5⟨σ222⟩*var"Γ_{2,1}" + (0 + 1im)*⟨σ222⟩*var"Ω_{2,1}" + (0 + 1im)*conjexpRO_1*⟨⟨σ212⟩⟩*ΩROs + (0 - 2im)*conjexpRO_1*⟨⟨σ221*σ212⟩⟩*ΩROs + (0 - 1im)*expRO_2*⟨σ211⟩*ΩROs + (0 + 2im)*expRO_2*⟨σ211*σ222⟩*ΩROs
# ∂ₜ(⟨σ211*σ222⟩) = -0.5⟨σ221*σ212⟩*var"Γ_{2,1}" + (0 - 1im)*⟨σ221*σ212⟩*var"Ω_{2,1}" - 0.5⟨σ211*σ222⟩*var"Γ_{1,1}" - ⟨σ211*σ222⟩*var"Γ_{2,2}" + (0 - 2im)*conjexpRO_1*⟨σ221*σ222⟩*ΩROs + (0 + 1im)*conjexpRO_1*⟨σ222⟩*ΩROs + (0 + 1im)*conjexpRO_2*⟨σ211*σ122⟩*ΩROs + (0 - 1im)*expRO_2*⟨σ211*σ212⟩*ΩROs
# ∂ₜ(⟨σ221*σ212⟩) = -⟨σ221*σ212⟩*var"Γ_{1,1}" - 0.5⟨σ221*σ212⟩*var"Γ_{2,2}" - 0.5⟨σ211*σ222⟩*var"Γ_{1,2}" + (0 - 1im)*⟨σ211*σ222⟩*var"Ω_{1,2}" + (0 + 1im)*conjexpRO_1*⟨⟨σ211*σ122⟩⟩*ΩROs + (0 + 1im)*conjexpRO_2*⟨σ221⟩*ΩROs + (0 - 2im)*conjexpRO_2*⟨σ221*σ222⟩*ΩROs + (0 - 1im)*expRO_1*⟨σ211*σ212⟩*ΩROs
# ∂ₜ(⟨σ221*σ222⟩) = ⟨σ221*σ222⟩*(-var"Γ_{1,1}" - var"Γ_{2,2}") + (0 + 1im)*conjexpRO_1*⟨⟨σ211*σ222⟩⟩*ΩROs + (0 + 1im)*conjexpRO_2*⟨⟨σ221*σ212⟩⟩*ΩROs + (0 - 1im)*expRO_1*⟨σ211*σ222⟩*ΩROs + (0 - 1im)*expRO_2*⟨σ221*σ212⟩*ΩROs
# ∂ₜ(⟨σ211*σ212⟩) = -0.5⟨σ211*σ212⟩*(var"Γ_{1,1}" + var"Γ_{2,2}") + (0 - 2im)*conjexpRO_1*⟨σ221*σ212⟩*ΩROs + (0 + 1im)*conjexpRO_1*⟨σ212⟩*ΩROs + (0 + 1im)*conjexpRO_2*⟨σ211⟩*ΩROs + (0 - 2im)*conjexpRO_2*⟨σ211*σ222⟩*ΩROs

# %% [markdown]
# ### Evaluate parameters

# %%
Γij_symb = [Γ(i,j) for i = 1:N for j=1:N]
Ωij_symb = [Ω(i,j) for i = 1:N for j=1:N if i≠j]

Γij_ = [Γ_CS[i, j] for i = 1:N for j=1:N]
Ωij_ = [Ω_CS[i, j] for i = 1:N for j=1:N if i≠j]

exp_RO_symb = [exp_RO(i) for i = 1:N]
conj_exp_RO_symb = [conj_exp_RO(i) for i = 1:N]

exp_RO_ = [exp(1im*r0[i]'kl) for i =1:N]
conj_exp_RO_ = [exp(-1im*r0[i]'kl) for i =1:N]



ps = [Γij_symb; Ωij_symb; exp_RO_symb; conj_exp_RO_symb; ΩROs]
p0 = [Γij_; Ωij_; exp_RO_; conj_exp_RO_; Ω_RO/2]

p0 = ps .=> p0;

# %%
eqs_eval = substitute(eqs_eval, Dict(p0))
# Out:
# ∂ₜ(⟨σ221⟩) = (6.612998626133381e-16 + 0.1529051987767584im)*⟨⟨σ211⟩⟩ - ⟨σ221⟩ - 0.5((-0.16912923915169997 + 0.0im)⟨⟨σ211*σ122⟩⟩ + (-0.16912923915169997 + 0.0im)⟨σ211*σ122⟩) + (0.0 - 0.10034254717755439im)*⟨⟨σ211*σ122⟩⟩ + (0.0 + 0.10034254717755439im)*⟨σ211*σ122⟩ + (6.612998626133381e-16 - 0.1529051987767584im)*⟨σ211⟩
# ∂ₜ(⟨σ222⟩) = -0.5((-0.16912923915169997 + 0.0im)⟨⟨σ211*σ122⟩⟩ + (-0.16912923915169997 + 0.0im)⟨σ211*σ122⟩) + (0.0 + 0.10034254717755439im)*⟨⟨σ211*σ122⟩⟩ + (0.0 - 0.10034254717755439im)*⟨σ211*σ122⟩ + (3.7795614933677915e-15 + 0.1529051987767584im)*⟨⟨σ212⟩⟩ + (3.7795614933677915e-15 - 0.1529051987767584im)*⟨σ212⟩ - ⟨σ222⟩
# ∂ₜ(⟨σ211⟩) = (6.612998626133381e-16 + 0.1529051987767584im) + (-1.3225997252266761e-15 - 0.3058103975535168im)*⟨σ221⟩ + (-0.16912923915169997 + 0.20068509435510878im)*⟨σ221*σ212⟩ + (0.08456461957584999 - 0.10034254717755439im)*⟨σ212⟩ - 0.5⟨σ211⟩
# ∂ₜ(⟨σ212⟩) = (3.7795614933677915e-15 + 0.1529051987767584im) - 0.5⟨σ212⟩ + (0.08456461957584999 - 0.10034254717755439im)*⟨σ211⟩ + (-0.16912923915169997 + 0.20068509435510878im)*⟨σ211*σ222⟩ + (-7.559122986735583e-15 - 0.3058103975535168im)*⟨σ222⟩
# ∂ₜ(⟨σ211*σ122⟩) = (0.08456461957584999 + 0.10034254717755439im)*⟨σ221⟩ + (-0.33825847830339995 + 0.0im)⟨σ221*σ222⟩ + -⟨σ211*σ122⟩ + (6.612998626133381e-16 + 0.1529051987767584im)*⟨⟨σ212⟩⟩ + (3.7795614933677915e-15 - 0.1529051987767584im)*⟨σ211⟩ + (-1.3225997252266761e-15 - 0.3058103975535168im)*⟨⟨σ221*σ212⟩⟩ + (-7.559122986735583e-15 + 0.3058103975535168im)*⟨σ211*σ222⟩ + (0.08456461957584999 - 0.10034254717755439im)*⟨σ222⟩
# ∂ₜ(⟨σ211*σ222⟩) = (-1.3225997252266761e-15 - 0.3058103975535168im)*⟨σ221*σ222⟩ + (0.08456461957584999 + 0.10034254717755439im)*⟨σ221*σ212⟩ + (3.7795614933677915e-15 + 0.1529051987767584im)*⟨σ211*σ122⟩ + (3.7795614933677915e-15 - 0.1529051987767584im)*⟨σ211*σ212⟩ - 1.5⟨σ211*σ222⟩ + (6.612998626133381e-16 + 0.1529051987767584im)*⟨σ222⟩
# ∂ₜ(⟨σ221*σ212⟩) = (3.7795614933677915e-15 + 0.1529051987767584im)*⟨σ221⟩ + (-7.559122986735583e-15 - 0.3058103975535168im)*⟨σ221*σ222⟩ + (6.612998626133381e-16 + 0.1529051987767584im)*⟨⟨σ211*σ122⟩⟩ - 1.5⟨σ221*σ212⟩ + (6.612998626133381e-16 - 0.1529051987767584im)*⟨σ211*σ212⟩ + (0.08456461957584999 + 0.10034254717755439im)*⟨σ211*σ222⟩
# ∂ₜ(⟨σ221*σ222⟩) = (-2.0 - 0.0im)⟨σ221*σ222⟩ + (3.7795614933677915e-15 - 0.1529051987767584im)*⟨σ221*σ212⟩ + (3.7795614933677915e-15 + 0.1529051987767584im)*⟨⟨σ221*σ212⟩⟩ + (6.612998626133381e-16 + 0.1529051987767584im)*⟨⟨σ211*σ222⟩⟩ + (6.612998626133381e-16 - 0.1529051987767584im)*⟨σ211*σ222⟩
# ∂ₜ(⟨σ211*σ212⟩) = (-1.3225997252266761e-15 - 0.3058103975535168im)*⟨σ221*σ212⟩ + (6.612998626133381e-16 + 0.1529051987767584im)*⟨σ212⟩ + (3.7795614933677915e-15 + 0.1529051987767584im)*⟨σ211⟩ + -⟨σ211*σ212⟩ + (-7.559122986735583e-15 - 0.3058103975535168im)*⟨σ211*σ222⟩

# %% [markdown]
# ### Compute variables

# %%
# Save the expectation values of the operators which differential equation has to be solved
op_list = []
var_array = []
for i in 1:length(eqs_eval)
    var = eqs_eval[i].lhs
    push!(var_array, var)
    
    v_str = string(var)
    em = eachmatch(r"σ(\d+)", v_str)
    ind = [m.captures[1] for m in em]
    push!(op_list, [parse(Int, i) for i in ind])
end
@save "op_list.jdl2" op_list

# %% [markdown]
# ### Build function

# %%
if !isdir("Cfunctions")
    mkdir("Cfunctions")
end


for i in 1:length(eqs_eval)
    # Save the C function
    code = Symbolics.build_function([eqs_eval[i].rhs], var_array, target=Symbolics.CTarget())
    c_code = replace(code, 
        "im" => "*I", "double* du" => "double complex* du", "const double* RHS1" => "const double complex* RHS1", "du[0]" => "du[$(i-1)]", "diffeqf" => "diffeqf_$i")
    open("Cfunctions/diffeqf_$i.c", "w") do io
        print(io, "#include <complex.h>\n") # Include complex package
        print(io, c_code)
    end
    # Free RAM memomry
    code = nothing
    c_code = nothing
end

# %% [markdown]
# ### Build dispatcher

# %%
""" Create the big function that will call all the subfunctions to avoid doing a lot of ccalls """
function generate_full_dispatcher(filename::String, n::Int)
    open(filename, "w") do io
        println(io, "#include <complex.h>\n#include <math.h>\n")
        # External subfunctions
        for i in 1:(n)
            println(io, "extern void diffeqf_$i(double complex* du, const double complex* RHS1);")
        end

        println(io, "\nvoid diffeqf(double complex* du, const double complex* RHS1) {")

        # Call the subfunctions
        for i in 1:(n)
            println(io, "    diffeqf_$i(du, RHS1);")
        end

        println(io, "}")
    end
end

generate_full_dispatcher("dispatcher.c", length(eqs_eval))

# %% [markdown]
# ### Build object file

# %%
""" Create the object file (with the name of all the functions and their corresponding files) to avoid compilation issue """
function objs_file()
    open("objs.txt", "w") do io
         println(io, "dispatcher.o")
        for i in 1:length(eqs_eval)
            println(io, "Cfunctions/diffeqf_$i.o")
        end
    end
end

objs_file()
