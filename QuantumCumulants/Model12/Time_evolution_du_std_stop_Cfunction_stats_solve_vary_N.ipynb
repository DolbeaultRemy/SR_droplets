# %%
include("MiniCollectiveSpins.jl")
using PyPlot
using Statistics
using JLD2
using OrdinaryDiffEq
using DiffEqCallbacks
import PhysicalConstants.CODATA2018: c_0
using Unitful
using ProgressMeter
using ProgressBars
using NonlinearSolve
using BenchmarkTools
using Libdl

# %%
""" Prepare the initial vector u0 """
function u0_CFunction(phi_array, theta_array, op_list)
    u0 = ones(ComplexF64, length(op_list))
    for i in 1:length(op_list)
        if length(op_list[i]) == 1
            j = Int(op_list[i][1] % 10^floor(log10(abs(op_list[i][1]))-1)) # Atom nbr
            if parse(Int, string(op_list[i][1])[1:2]) == 22
                u0[i] = cos(theta_array[j]/2)^2
            elseif parse(Int, string(op_list[i][1])[1:2]) == 21
                u0[i] = cos(theta_array[j]/2)*exp(1im*phi_array[j])*sin(theta_array[j]/2)
            else
                println(op_list[i][1])
            end
        end

        if length(op_list[i]) == 2
            for op in op_list[i]
                j = Int(op % 10^floor(log10(abs(op))-1)) # Atom nbr
                if parse(Int, string(op)[1:2]) == 22
                    u0[i] *= cos(theta_array[j]/2)^2
                elseif parse(Int, string(op)[1:2]) == 21
                    u0[i] *= cos(theta_array[j]/2)*exp(1im*phi_array[j])*sin(theta_array[j]/2)
                elseif parse(Int, string(op)[1:2]) == 12
                    u0[i] *= cos(theta_array[j]/2)*exp(-1im*phi_array[j])*sin(theta_array[j]/2)
                else
                    println(op)
                end
            end
        end
    end
    return u0
end


""" Create a random distribution, save it, computes the corresponding parameters an return the stationnary state. 
If compute_t_evolution, compute the whole evolution, else only the stationnary state. """
function solve_random_distrib(chunk, f, op_list, N, n, d0_lb, threshold_du, threshold_std, t_std, f_counter, save_sol)
    list_t, popup_t, nbr_error_t, sol_t, du_t = [], [], [], [], []

    for i in chunk
        # Compute distribution
        L = (N/n)^(1/3) # Change the volume to keep the density cste
        r0 = [[rand(Float64)*L, rand(Float64)*L, rand(Float64)*L] for i in 1:N]

        # Choose a distribution where the minimum distance between the atoms is bigger than d0_min
        while min_r0(r0) < d0_lb
            r0 = [[rand(Float64)*L, rand(Float64)*L, rand(Float64)*L] for i in 1:N]
        end

        # Save the atoms position for comparison with QuantumOptics
        @save "r0/r0_N_$(N)_r_$i.jdl2" r0 L

        # Compute the parameters
        system = SpinCollection(r0, e, gammas=1.)
        Ω_CS = OmegaMatrix(system)
        Γ_CS = GammaMatrix(system)
        Γij_ = [Γ_CS[i, j] for i = 1:N for j=1:N]
        Ωij_ = [Ω_CS[i, j] for i = 1:N for j=1:N if i≠j]
        exp_RO_ = [exp(1im*r0[i]'kl) for i = N:-1:1] # We go in the decreasing direction to avoid exp_RO(10) being replace by exp_RO(1)0
        conj_exp_RO_ = [exp(-1im*r0[i]'kl) for i = N:-1:1]
        p0 = ComplexF64.([Γij_; Ωij_; exp_RO_; conj_exp_RO_; Ω_RO/2])
        
        # Load the functions
        fsolve(du, u, p, t) = functions[f_counter](du, u, p0)

        phi_array_0, theta_array_0 = zeros(N), ones(N)*π # We start from all the atoms in the GS
        u0 = u0_CFunction(phi_array_0, theta_array_0, op_list)

        du_save = []
        function stop_condition(u, t, integrator)
            if t > t_std+1 # To compute the std over a big enough nbr of points
                # Condition on the derivatives near 0
                du = similar(u)
                fsolve(du, u, integrator.p, t)
                if length(du_save) > 0 # Normalize du by the first value
                    push!(du_save, norm(du[1:N])/du_save[1])
                    condition_du = du_save[end] < threshold_du
                else
                    push!(du_save, 1)
                    condition_du = false
                end


                # Condition on the density of atoms in the ES that has to be stable
                u_t, t_sol = integrator.sol.u, integrator.sol.t
                n_es = [sum(real([u_t[j][i] for i = 1:N])) for j = 1:length(t_sol)] # Computes the density
                n_es_window_t = n_es[abs.(t_sol .- integrator.t) .< t_std]
                std_es_window_t = std(n_es_window_t)
                condition_std = std_es_window_t < threshold_std
                return condition_du & condition_std
            else
                return false
            end
        end

        function affect!(integrator)
            terminate!(integrator) # If stop conditions are met, stop the solver
        end
        
        stop_cb = DiscreteCallback(stop_condition, affect!)

        prob = OrdinaryDiffEq.ODEProblem(fsolve, u0, (0, t_end))
        
        sol = OrdinaryDiffEq.solve(prob, OrdinaryDiffEq.DP5();
                    reltol=1.0e-5,
                    abstol=1.0e-5,
                    callback = stop_cb,
                    dtmin = 1e-2)

        push!(list_t, sol.t)
        push!(popup_t, [sum(real(sol.u[i][1:N])) for i=1:length(sol.t)])
        push!(du_t, du_save)

        if save_sol
            push!(sol_t, sol.u)
        end

        if ~SciMLBase.successful_retcode(sol) | (list_t[end][end] == t_end) # If solution DV, add it to the error, or if it can't find a SS
            push!(nbr_error_t, i)
        end
    end
    return list_t, popup_t, nbr_error_t, sol_t, du_t
end

""" Return the minimum distance of a distribution of atoms r0 """
function min_r0(r0)
    N = length(r0)
    d0 = zeros(N, N) # Repetiton, atom i, distance from atom j
    for j in 1:N
        for k = 1:N
            d0[j, k] = norm(r0[j]-r0[k])
        end
    end
    return minimum(d0[d0 .> 0])
end

""" Function loading the block subfunction when a lot of equations are involved """
function load_f(fname::String, libpath::String)
	lib = Libdl.dlopen(libpath)
	fptr = Libdl.dlsym(lib, fname)
	return (du, u, params) -> ccall(fptr, Cvoid, (Ptr{ComplexF64}, Ptr{ComplexF64}, Ptr{ComplexF64}), du, u, params)
end
# Out:
# load_f

# %% [markdown]
# ### Define the system

# %%
# Nbr of particles
N_list = [2:2:20;]
r = 100
 # Nbr of repetitions

# Normalisation parameters
λ = 421e-9
γ = 32.7e6 # In Hz

# Physical values
ω0 = (2π*ustrip(c_0)/λ)
ωl = ω0
kl = [ustrip(c_0)/ωl, 0, 0] # Laser along x
Ω_RO = 1e7 # Taken from Barbut arXiv:2412.02541v1

# Fixed density
n0 = 1000 #2e3 # atoms per unit of volume (already normalized)
d0_lb = 5e-10 # Minimum distance between the atoms (lower boundary) in m

# Normalization
ω0 = ω0 / γ
ωl = ωl / γ
kl = kl * λ 
Ω_RO = Ω_RO / γ
d0_lb = d0_lb / λ

# Quantization axis along z
e = [0, 0, 1.]

# Integration parameter
t_end = 1e2
threshold_du = 1e-2
threshold_std, t_std = 1e-3, 10; # Time over which the std is computed

# %% [markdown]
# ### Compute stationnary state for r repetitions

# %%
# Create the directories
if !isdir("r0")
    mkdir("r0")
end
if !isdir("Images_distribution")
    mkdir("Images_distribution")
end
if !isdir("solutions")
    mkdir("solutions")
end
nothing

# %%
# Prepare the wrapper
const N_FUNCS = length(N_list)  # Total function nbr
const functions = Vector{Function}(undef, N_FUNCS)

for (i, N) in enumerate(N_list)
    libpath ="libs/liballfuncs_$N.dll"
    functions[i] = load_f("diffeqf", libpath)
end

# %%
list_r = 1:r
chunks = Iterators.partition(list_r, cld(length(list_r), Threads.nthreads()))
popup_t_N, list_t_N, nbr_error_t_N, sol_t_N, du_t_N = [], [], [], [], []

for (i, N) in ProgressBar(enumerate(N_list))
    @load "op_list/op_list_$N.jdl2" op_list
    tasks = map(chunks) do chunk # Split the different distributions into chuncks solved on each core
        Threads.@spawn solve_random_distrib(chunk, functions, op_list, N, n0, d0_lb, threshold_du, threshold_std, t_std, i, true)
    end
    sol_tasks = fetch.(tasks)
    push!(list_t_N, vcat([s[1] for s in sol_tasks]...))
    push!(popup_t_N, vcat([s[2] for s in sol_tasks]...))
    push!(nbr_error_t_N, vcat([s[3] for s in sol_tasks]...))
    push!(sol_t_N, vcat([s[4] for s in sol_tasks]...))
    push!(du_t_N, vcat([s[5] for s in sol_tasks]...))
end
# Out:
# 0.0%┣                                              ┫ 0/10 [00:01<00:-12, -1s/it]
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=1.9897194027245155, and step error estimate = 0.6199565726122955. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# 10.0%┣████▏                                     ┫ 1/10 [00:10<Inf:Inf, InfGs/it]
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 341.8381430580411. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 3450.464675611117. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.011870936523882613, and step error estimate = 0.6732834230822624. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 4360.885845238149. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 516125.88384440937. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.013302004538997925, and step error estimate = 0.6726653719737778. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.499218399014952, and step error estimate = 0.5028992305892173. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 8042.163992994202. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 662.2388968376514. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.21610582575694573, and step error estimate = 0.6363167746721388. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.36106509553575555, and step error estimate = 0.5778952599631406. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 234.6221985432486. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.015115701998526793, and step error estimate = 0.7019579352010864. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.3031199992899412, and step error estimate = 0.6215979239579132. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.012431894330597335, and step error estimate = 0.6914223195601148. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 214.90092376589132. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.413628682964347, and step error estimate = 0.49269441621256976. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.013144868295528196, and step error estimate = 0.6610505209324252. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# 20.0%┣█████████▏                                    ┫ 2/10 [00:12<01:37, 12s/it]
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.15584996339695908, and step error estimate = 0.8481821790938928. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 2.7635446603055024e8. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.22665157595645158, and step error estimate = 0.7267419447620559. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.010727471180258186, and step error estimate = 0.6062757784679795. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.3570903972499954, and step error estimate = 0.5559825629582913. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=1.004519521480085, and step error estimate = 0.6183164569883659. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 2301.5104699992708. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.5845710219420959, and step error estimate = 0.6148640366981067. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 529.1222295652199. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 308.95063252645934. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.21895628489465246, and step error estimate = 0.5482147481625688. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.014947512947252925, and step error estimate = 0.6584150355186126. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 1328.384957108454. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.38284360121369404, and step error estimate = 0.5116851783729133. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.30063624886692, and step error estimate = 0.5339896883217552. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 1.2583695169747923e11. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 729.66982047047. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.17220102288348552, and step error estimate = 0.5904875847402956. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.34020719451754294, and step error estimate = 0.5753047331046324. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 891.605366786967. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# 30.0%┣██████████████                                 ┫ 3/10 [00:18<01:04, 9s/it]
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 4.5909024804721335e6. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.23121981321930646, and step error estimate = 0.6106403231715012. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.3444309343360529, and step error estimate = 0.5775832573294793. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.010770133969928554, and step error estimate = 0.5516973991826266. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 4214.2481958807975. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 3.065012408280975e6. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.014456982797252695, and step error estimate = 0.634971738196806. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 3.343483787813848e8. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 1592.2623774639376. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.6367433672859008, and step error estimate = 0.589961285204196. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.4921900480982514, and step error estimate = 0.5471190537120955. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.012202075227516745, and step error estimate = 0.5934283812013602. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.30644191321067643, and step error estimate = 0.6097118176939482. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 6211.026706486748. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 1.6494294832577262e7. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 2.5849118252602756e14. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.011979049487066361, and step error estimate = 0.5912269315377945. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=1.6540220606626865, and step error estimate = 0.6440122840143396. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 1380.228203484078. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.011314587926209353, and step error estimate = 0.49673535048233275. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 7.035365333948771e6. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.23059572955760851, and step error estimate = 0.5284189901742722. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 141651.4834375902. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.19190936649211568, and step error estimate = 0.6264255421213404. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 3645.8370063846182. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.014712831017006501, and step error estimate = 0.6350600198342842. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.012999493241450073, and step error estimate = 0.6041648065324561. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.3048190618382781, and step error estimate = 0.5402940665653306. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.013767384758049445, and step error estimate = 0.6270720978828795. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.012130781040049823, and step error estimate = 0.6016237412044122. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.3188441713912259, and step error estimate = 0.5949049591331673. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 51897.96855319371. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.3589838492725654, and step error estimate = 0.5792215069496841. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.584711726548311, and step error estimate = 0.5940746045561025. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# 40.0%┣██████████████████▍                           ┫ 4/10 [00:34<01:09, 11s/it]
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.6336119742550557, and step error estimate = 0.5554908714392505. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 7.310532730335889e10. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.7685462149700223, and step error estimate = 0.6115534931217111. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.70555970123963, and step error estimate = 0.5946701745517828. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.13668520046068863, and step error estimate = 0.6449577352863368. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 4.8326927919582963e8. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.01430903282477382, and step error estimate = 0.5758891116552532. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.07624612217969305, and step error estimate = 0.8580998956993802. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=1.6934745013304373, and step error estimate = 0.6391724975883948. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.011841008037236362, and step error estimate = 0.5561024488060934. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 295620.32114665926. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.014070651360732689, and step error estimate = 0.5903171296086892. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.1912265150610041, and step error estimate = 0.6317229162161299. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.18047339132833504, and step error estimate = 0.6675705366309153. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 6.055454157545474e6. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 469.3667218744164. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.011239571737308026, and step error estimate = 0.5678324439801656. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 1552.4947234194065. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 3.7757299801480277e6. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.013014647812509503, and step error estimate = 0.5756515279988882. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.013293070768467887, and step error estimate = 0.5808946512405037. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.013413318951147186, and step error estimate = 0.614439280940769. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0951013945856383, and step error estimate = 0.9639544928698845. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 783.7285493135663. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.011946648954085008, and step error estimate = 0.5691136761286203. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0145511978596585, and step error estimate = 0.6290364511286801. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.24727833840231875, and step error estimate = 0.6080785841350557. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.2856616199683894, and step error estimate = 0.5371562261951532. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.15180865919369957, and step error estimate = 0.5873212680254053. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.1921898069294466, and step error estimate = 0.638082658169419. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 3.663678958747853e13. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.3846813495349249, and step error estimate = 0.6015961117683271. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.5336684289056794, and step error estimate = 0.597519913639725. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 559.742568930305. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.11018554191909878, and step error estimate = 0.9283221455383737. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.2630242855491275, and step error estimate = 0.5337834653990637. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.30061038071453106, and step error estimate = 0.4986660705588612. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.18068424205413514, and step error estimate = 0.629399191792856. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.30412822122581573, and step error estimate = 0.5633155791058307. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 1892.9259267361142. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# 50.0%┣███████████████████████                       ┫ 5/10 [01:36<02:00, 24s/it]
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=1.7623200291919403, and step error estimate = 0.6211267823571378. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.014701968082428244, and step error estimate = 0.6008792277758893. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.18241193695793292, and step error estimate = 0.6185617431938901. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 1484.6823866950476. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 4.941122885528691e10. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 16476.567456287394. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 8.808696389363055e7. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.9660979461460517, and step error estimate = 0.6219852441965047. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.4010695820169476, and step error estimate = 0.605474147981674. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.010889079879929278, and step error estimate = 0.5569318207993286. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.01410068342474079, and step error estimate = 0.5052309259524257. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 825.8899502653426. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 2.3428364347948193e10. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.06294095933120691, and step error estimate = 1.048093566954045. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 1033.478651389466. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 1533.889456918058. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 1279.099082339394. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.2394862033816344, and step error estimate = 0.6198750917856171. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0892432608593631, and step error estimate = 0.8805221842728083. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 3127.718642048124. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 2.337010144795629e6. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 584.9253592380312. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.33281092194405665, and step error estimate = 0.6059665161004374. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.7098161980747832, and step error estimate = 0.5691247073219377. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.7469776417710928, and step error estimate = 0.5956731364090325. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.14423400745011997, and step error estimate = 0.5369818068387883. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 6393.590643300539. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.012234648331097435, and step error estimate = 0.5523926636850591. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 940.4390581709033. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.09159222897143213, and step error estimate = 0.8623401842854249. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.3439040276745791, and step error estimate = 0.46299377943906656. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 1.1574700612561507e7. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.01039265231476809, and step error estimate = 0.5604105425504702. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.011856084151293285, and step error estimate = 0.5575280449002215. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.163770655453448, and step error estimate = 0.5975797920043722. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.013020363153332996, and step error estimate = 0.5681407435178235. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.20613436107113897, and step error estimate = 0.6007011116370946. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.17967476549373487, and step error estimate = 0.6291492245351763. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 1449.2606022349091. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# 60.0%┣███████████████████████████▋                  ┫ 6/10 [03:44<02:59, 45s/it]
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 2366.986032781709. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.011018346158172307, and step error estimate = 0.5527425279923954. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.01124435307687025, and step error estimate = 0.5496289490117001. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.12468709931634403, and step error estimate = 0.8064433185273951. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 22140.045560383736. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.12416761791223445, and step error estimate = 0.7136410606110825. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.013543463971118936, and step error estimate = 0.5768817892362073. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.41856759114843767, and step error estimate = 0.5970306727373825. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.43314449253535114, and step error estimate = 0.6007735599937057. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 1672.379147123524. Aborting. There is either an error in your model specification or the true solution is unstable.
# ...
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.011476565920870567, and step error estimate = 0.5570462224394178. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.5714699480073575, and step error estimate = 0.45063852211197075. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 1.6213927964288902e10. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.07638053636531056, and step error estimate = 0.9840487007007074. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 2.0515033138046355e9. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.09223950739697755, and step error estimate = 0.9363752971272499. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 2098.691171349211. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.36883240645422954, and step error estimate = 0.5612305774276223. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.6601782382296677, and step error estimate = 0.6008345543109783. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=1.1562251742093907, and step error estimate = 0.6282254985356807. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 8852.799470441127. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 1317.141039804947. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=2.0447128494406774, and step error estimate = 0.5776203508814237. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 3.6076096870473285e11. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 6.852370780641694e9. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 404107.0852346196. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 3.40753979299846e22. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.1709549018895954, and step error estimate = 0.5981721581512249. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.09855395060784863, and step error estimate = 0.8021298361591879. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.013267777699728258, and step error estimate = 0.5485797811621361. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.8971856997904846, and step error estimate = 0.6092967427364314. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.92387352815342, and step error estimate = 0.5801859287160269. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.06304004427014066, and step error estimate = 1.5474106037042608. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 749.1804823338708. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 169681.7479681627. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.1296231589773363, and step error estimate = 0.6768243573970729. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 630.4161238136574. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.010874030830809437, and step error estimate = 0.5880991237826834. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=2.6692178211926563, and step error estimate = 0.6398380052716408. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 1367.1439838263825. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.05450252092094882, and step error estimate = 2.3526554227883514. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.01435258153036011, and step error estimate = 0.5444453885839802. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 8.236796090549186e7. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.012254036773632989, and step error estimate = 0.5241277452956291. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0744101118734385, and step error estimate = 4.196535803918095. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 1193.1767082010742. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 683006.1421045046. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=77.42889500118831, and step error estimate = 0.4759901259613613. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.07717326703201427, and step error estimate = 4.074932250630649. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.1314101826880736, and step error estimate = 0.6105614884843492. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 5.904858981062723e7. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=21.609808569916513, and step error estimate = 0.4447154097978123. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 1.1282652958099797e11. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.01110161691997995, and step error estimate = 0.5714933828236125. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0115487760086935, and step error estimate = 0.5636268625323787. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0806869037789018, and step error estimate = 0.8602895028968782. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 8004.572682990649. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.13261511452702532, and step error estimate = 0.5897964890862523. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 3283.2571450918444. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 89392.64206177296. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 1.1184843197420847e6. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.06757336346440104, and step error estimate = 1.38314891190198. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.0, and step error estimate = 7458.061523113065. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# ┌ Warning: dt(0.01) <= dtmin(0.01) at t=0.01229108082535652, and step error estimate = 0.5399595474581023. Aborting. There is either an error in your model specification or the true solution is unstable.
# └ @ SciMLBase C:\Users\Joschka\.julia\packages\SciMLBase\TZ9Rx\src\integrator_interface.jl:653
# 100.0%┣███████████████████████████████████████████┫ 10/10 [54:31<00:00, 363s/it]
# 100.0%┣███████████████████████████████████████████┫ 10/10 [54:31<00:00, 363s/it]

# %%
@save "solutions/sol_N_$(N_list)_r_$(r).jld2" list_t_N popup_t_N nbr_error_t_N sol_t_N du_t_N

# %%
# @load "solutions/sol_N_$(N_list)_r_$(r).jld2" list_t_N popup_t_N nbr_error_t_N sol_t_N du_t

# %% [markdown]
# # Plots with time evolution

# %%
fig, ax = subplots()
for i in 1:length(popup_t_N)
    line = []
    for j in 1:length(popup_t_N[i])
        if j ∉ nbr_error_t_N[i]
            if line == []
                line, = ax.plot(list_t_N[i][j], popup_t_N[i][j], marker="o", markersize=1, label=N_list[i])
            else
                ax.plot(list_t_N[i][j], popup_t_N[i][j], marker="o", markersize=1, color=line.get_color())
            end
        end
    end
end


ax.set_xlabel(L"$\gamma t$")
ax.set_ylabel(L"$\langle  n_{\uparrow} \rangle $")
ax.legend()

suptitle("N = $N_list, r = $r, Starting from "*L"$|\downarrow \downarrow \rangle $")
pygui(false); gcf();
# pygui(true); show()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# # Mean of the SS

# %%
mean_SS = mean.([[popup_t_N[i][j][end] for j = 1:length(popup_t_N[i])] for i = 1:length(popup_t_N)])
std_SS = std.([[popup_t_N[i][j][end] for j = 1:length(popup_t_N[i])] for i = 1:length(popup_t_N)])

fig, axes = subplots(1, 2, figsize = (15, 5))
axes[1].errorbar(N_list, mean_SS, yerr=std_SS)
axes[1].set_xlabel("N")
axes[1].set_ylabel(L"$\langle  N_{\uparrow}^{SS} \rangle $")

axes[2].errorbar(N_list, mean_SS./N_list, yerr=std_SS./N_list)
axes[2].set_xlabel("N")
axes[2].set_ylabel(L"$\langle  n_{\uparrow}^{SS} \rangle $")

pygui(false); gcf();
# pygui(true); show()
# Out:
# Figure(PyObject <Figure size 1500x500 with 2 Axes>)

# %% [markdown]
# # Plot the evolutions that didn't work

# %%
close("all")
fig, axes = subplots(1, 2, figsize=(10, 5))
for i in 1:length(popup_t_N)
    for j in 1:length(popup_t_N[i])
        @load "r0/r0_N_$(N_list[i])_r_$j.jdl2" r0 L
        if j ∈ nbr_error_t_N[i]
            axes[1].plot(list_t_N[i][j], popup_t_N[i][j], marker="o", markersize=1, label="N=$(N_list[i]), r=$j")
            axes[2].scatter(N_list[i], min_r0(r0), color ="r")
        else
            axes[2].scatter(N_list[i], min_r0(r0), color ="b")
        end

    end
end
axes[2].hlines(d0_lb, N_list[1], N_list[end])
axes[1].set_xlabel(L"$\gamma t$")
axes[1].set_ylabel(L"$\langle  n_{\uparrow} \rangle $")
axes[2].set_xlabel(L"N")
axes[2].set_ylabel(L"min(r_0)")
# axes[1].legend()
pygui(false); gcf();
# pygui(true); show()
# Out:
# Figure(PyObject <Figure size 1000x500 with 2 Axes>)

# %% [markdown]
# # Timestep

# %%
close("all")
fig, ax = subplots()
for i in 1:length(popup_t_N)
    line = []
    for j in 1:length(popup_t_N[i])
        T = list_t_N[i][j]
        if j == 1
            line, = ax.plot(T[1:end-1], T[2:end]-T[1:end-1], label=N_list[i])
        else
            ax.plot(T[1:end-1], T[2:end]-T[1:end-1], color=line.get_color())
        end
    end
end


ax.set_xlabel(L"$\gamma t$")
ax.set_ylabel(L"$\Delta T$")
ax.legend()
pygui(false); gcf();
# pygui(true); show()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %% [markdown]
# # Show condition evolution

# %%
close("all")
fig, axes = subplots(1, 2, figsize=(15, 5))
for i in 1:length(popup_t_N)
    line = []
    for j in 1:length(popup_t_N[i])
        if j ∉ nbr_error_t_N[i]
            T, popup = list_t_N[i][j], popup_t_N[i][j]
            std_es_window_t = []
            for t in 1:length(T)
                if T[t] > t_std+1
                    popup_window = popup[abs.(T .- T[t]) .< t_std]
                    push!(std_es_window_t, std(popup_window))
                end
            end
            if line == []
                line, = axes[1].plot(T[T .> t_std+1], std_es_window_t, marker="o", markersize=2, label=N_list[i])
            else
                axes[1].plot(T[T .> t_std+1], std_es_window_t, marker="o", markersize=2, color=line.get_color())
            end
            
            axes[2].plot(T[T .> t_std+1][1:length(du_t_N[i][j])], du_t_N[i][j], color=line.get_color())
        end
    end
end

axes[1].hlines(threshold_std, 0, t_end)
axes[1].set_xlabel(L"$\gamma t$")
axes[1].set_ylabel(L"$std(n^\uparrow_{window})$")
axes[1].legend()

axes[2].hlines(threshold_du, 0, t_end)
axes[2].set_xlabel(L"$\gamma t$")
axes[2].set_ylabel(L"$mean(\partial_t u)$")

# pygui(false); gcf();
pygui(true); show()

# %% [markdown]
# # Brouillons

# %%
# for (i, N) in enumerate(N_list)
#     line = []
#     for j in 1:length(popup_t_N[i])
#         condition_du = []
#         T, u_t = list_t_N[i][j], sol_t_N[i][j]
#         @load "r0/r0_N_$(N_list[i])_r_$i.jdl2" r0 L

#         # Compute the parameters
#         system = SpinCollection(r0, e, gammas=1.)
#         Ω_CS = OmegaMatrix(system)
#         Γ_CS = GammaMatrix(system)
#         Γij_ = [Γ_CS[i, j] for i = 1:N for j=1:N]
#         Ωij_ = [Ω_CS[i, j] for i = 1:N for j=1:N if i≠j]
#         exp_RO_ = [exp(1im*r0[i]'kl) for i = N:-1:1] # We go in the decreasing direction to avoid exp_RO(10) being replace by exp_RO(1)0
#         conj_exp_RO_ = [exp(-1im*r0[i]'kl) for i = N:-1:1]
#         p0 = ComplexF64.([Γij_; Ωij_; exp_RO_; conj_exp_RO_; Ω_RO/2])
        
#         # Load the functions
#         fsolve(du, u, p) = functions[i](du, u, p0)

#         for t in 1:length(T)
#             du = similar(u_t[1])
#             du = zeros(length(du))
#             # println(du)
#             fsolve(du, u_t[t], p0)
#             push!(condition_du, norm(du)/sqrt(length(du)))
#         end

#         if line == []
#             line, = axes[2].plot(T, condition_du, marker="o", markersize=2, label=N_list[i])
#         else
#             axes[2].plot(T, condition_du, marker="o", markersize=2, color=line.get_color())
#         end
#     end
# end
