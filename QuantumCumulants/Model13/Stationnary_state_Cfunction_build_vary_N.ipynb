# %%
using QuantumCumulants
using Symbolics
using JLD2
using ProgressMeter
using ProgressBars

# %%
Threads.nthreads()
# Out:
# 5

# %%
""" Create the big function that will call all the subfunctions to avoid doing a lot of ccalls """
function generate_full_dispatcher(filename::String, n::Int)
    open(filename, "w") do io
        println(io, "#include <complex.h>\n#include <math.h>\n")
        # External subfunctions
        for i in 1:(n)
            println(io, "extern void diffeqf_$i(double complex* du, const double complex* RHS1);")
        end

        println(io, "\nvoid diffeqf(double complex* du, const double complex* RHS1) {")

        # Call the subfunctions
        for i in 1:(n)
            println(io, "    diffeqf_$i(du, RHS1);")
        end

        println(io, "}")
    end
end


""" Create the object file (with the name of all the functions and their corresponding files) to avoid compilation issue """
function objs_file(eqs_eval)
    open("objs.txt", "w") do io
         println(io, "dispatcher.o")
        for i in 1:length(eqs_eval)
            println(io, "Cfunctions/diffeqf_$i.o")
        end
    end
end


""" Function creating the makefile for the corresponding HT frequency """
function change_mkfile(N)
    write("Makefile", replace(read("MakefileTemplate.txt", String), "liballfuncs.dll"=>"libs/liballfuncs_$N.dll"))
end


""" Function that writes the Cfunctions, used to be distributed between all the threads """
function write_c_func(eqs, chunk, var_array, p0)
    for i in chunk
        code = Symbolics.build_function([eqs[i].rhs], var_array, target=Symbolics.CTarget())
        c_code = replace(code, 
            "im" => "*I", "double* du" => "double complex* du", "const double* RHS1" => "double complex* RHS1, const double complex* parameters", "du[0]" => "du[$(i-1)]", "diffeqf" => "diffeqf_$i")
        # Replace the parameters by a parametor vector
        c_code = replace(c_code, p0...)
        open("Cfunctions/diffeqf_$i.c", "w") do io
            print(io, "#include <complex.h>\n") # Include complex package
            print(io, c_code)
        end
    end
end
# Out:
# write_c_func

# %%
# Nbr of atoms
N_list = [2:2:30;];

# %% [markdown]
# # Derivation of the symbolic MPC equations

# %%
@cnumbers Nsymb ΩROs

h = NLevelSpace(Symbol(:atom),2)

exp_RO(i) = IndexedVariable(:expRO, i)
conj_exp_RO(i) = IndexedVariable(:conjexpRO, i)
Γ(i,j) = IndexedVariable(:Γ,i,j)
Ω(i,j) = IndexedVariable(:Ω,i,j;identical=false)

i = Index(h,:i,Nsymb,h)
j = Index(h,:j,Nsymb,h)
k = Index(h,:k,Nsymb,h)

σ(x,y,z) = IndexedOperator(Transition(h,:σ,x,y),z)

H_RO = ΩROs * ∑(exp_RO(i)*σ(2,1,i) + conj_exp_RO(i)*σ(1,2,i), i)
H_elec = Σ(Ω(i,j)*σ(2,1,i)*σ(1,2,j), j, i)

H = Symbolics.simplify(H_RO + H_elec)

J = [σ(1,2,i)] # σ-, jump operators for the Lindbladian
rates = [Γ(i,j)]

ops = [σ(2, 2, k), σ(2, 1, k)]; # n_up/σ+

# %%
eqs = meanfield(ops,H,J;rates=rates,order=2)
complete!(eqs);

# %% [markdown]
# # Build fonctions for each atom nbr

# %%
# Create the directories
if !isdir("Cfunctions")
    mkdir("Cfunctions")
end
if !isdir("libs")
    mkdir("libs")
end
if !isdir("op_list")
    mkdir("op_list")
end

# %%
@showprogress for N in N_list
    eqs_eval = QuantumCumulants.evaluate(eqs; limits=(Nsymb=>N))

    # Replace parameters by a big vector
    Γij_symb = [Γ(i,j) for i = 1:N for j=1:N]
    Ωij_symb = [Ω(i,j) for i = 1:N for j=1:N if i≠j]
    exp_RO_symb = [exp_RO(i) for i = N:-1:1] # We go in the decreasing direction to avoid exp_RO(10) being replace by exp_RO(1)0
    conj_exp_RO_symb = [conj_exp_RO(i) for i = N:-1:1]
    ps = [[string(Γ) for Γ in Γij_symb]; [string(Ω) for Ω in Ωij_symb]; [string(exp_RO) for exp_RO in exp_RO_symb]; [string(conj_exp_RO) for conj_exp_RO in conj_exp_RO_symb]; string(ΩROs)]

    p0 = ["parameters[$(i-1)]" for i = 1:length(ps)]
    p0 = ps .=> p0
    
    # Compute variables
    op_list = []
    var_array = []
    for i in 1:length(eqs_eval)
        var = eqs_eval[i].lhs
        push!(var_array, var)
        
        v_str = string(var)
        em = eachmatch(r"σ(\d+)", v_str)
        ind = [m.captures[1] for m in em]
        push!(op_list, [parse(Int, i) for i in ind])
    end
    @save "op_list/op_list_$N.jdl2" op_list

    # Build Cfunctions
    list_eqs = 1:length(eqs_eval)
    chunks = Iterators.partition(list_eqs, cld(length(list_eqs), Threads.nthreads()))
    tasks = map(chunks) do chunk # Split the equations in chunck solved on each core
        Threads.@spawn write_c_func(eqs_eval, chunk, var_array, p0)
    end
    wait.(tasks)

    generate_full_dispatcher("dispatcher.c", length(eqs_eval))

    # Build object file
    objs_file(eqs_eval)
    
    # Change the makefile
    change_mkfile(N)

    # Compile C functions
    run(`make -j5`)
end
# Out:
# gcc -fPIC -c -Wall -O3 dispatcher.c -o dispatcher.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_1.c -o Cfunctions/diffeqf_1.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_2.c -o Cfunctions/diffeqf_2.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_3.c -o Cfunctions/diffeqf_3.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_4.c -o Cfunctions/diffeqf_4.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_5.c -o Cfunctions/diffeqf_5.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_6.c -o Cfunctions/diffeqf_6.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_7.c -o Cfunctions/diffeqf_7.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_8.c -o Cfunctions/diffeqf_8.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_9.c -o Cfunctions/diffeqf_9.o
# gcc -shared -o libs/liballfuncs_2.dll @objs.txt
# gcc -fPIC -c -Wall -O3 dispatcher.c -o dispatcher.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_1.c -o Cfunctions/diffeqf_1.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_10.c -o Cfunctions/diffeqf_10.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_11.c -o Cfunctions/diffeqf_11.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_12.c -o Cfunctions/diffeqf_12.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_13.c -o Cfunctions/diffeqf_13.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_14.c -o Cfunctions/diffeqf_14.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_15.c -o Cfunctions/diffeqf_15.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_16.c -o Cfunctions/diffeqf_16.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_17.c -o Cfunctions/diffeqf_17.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_18.c -o Cfunctions/diffeqf_18.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_19.c -o Cfunctions/diffeqf_19.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_2.c -o Cfunctions/diffeqf_2.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_20.c -o Cfunctions/diffeqf_20.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_21.c -o Cfunctions/diffeqf_21.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_22.c -o Cfunctions/diffeqf_22.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_23.c -o Cfunctions/diffeqf_23.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_24.c -o Cfunctions/diffeqf_24.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_25.c -o Cfunctions/diffeqf_25.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_26.c -o Cfunctions/diffeqf_26.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_27.c -o Cfunctions/diffeqf_27.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_28.c -o Cfunctions/diffeqf_28.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_29.c -o Cfunctions/diffeqf_29.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_3.c -o Cfunctions/diffeqf_3.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_30.c -o Cfunctions/diffeqf_30.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_31.c -o Cfunctions/diffeqf_31.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_32.c -o Cfunctions/diffeqf_32.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_33.c -o Cfunctions/diffeqf_33.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_34.c -o Cfunctions/diffeqf_34.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_35.c -o Cfunctions/diffeqf_35.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_36.c -o Cfunctions/diffeqf_36.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_37.c -o Cfunctions/diffeqf_37.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_38.c -o Cfunctions/diffeqf_38.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_4.c -o Cfunctions/diffeqf_4.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_5.c -o Cfunctions/diffeqf_5.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_6.c -o Cfunctions/diffeqf_6.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_7.c -o Cfunctions/diffeqf_7.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_8.c -o Cfunctions/diffeqf_8.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_9.c -o Cfunctions/diffeqf_9.o
# gcc -shared -o libs/liballfuncs_4.dll @objs.txt
# Progress:  13%|██████                                   |  ETA: 0:00:42
# gcc -fPIC -c -Wall -O3 dispatcher.c -o dispatcher.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_1.c -o Cfunctions/diffeqf_1.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_10.c -o Cfunctions/diffeqf_10.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_11.c -o Cfunctions/diffeqf_11.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_12.c -o Cfunctions/diffeqf_12.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_13.c -o Cfunctions/diffeqf_13.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_14.c -o Cfunctions/diffeqf_14.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_15.c -o Cfunctions/diffeqf_15.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_16.c -o Cfunctions/diffeqf_16.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_17.c -o Cfunctions/diffeqf_17.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_18.c -o Cfunctions/diffeqf_18.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_19.c -o Cfunctions/diffeqf_19.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_2.c -o Cfunctions/diffeqf_2.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_20.c -o Cfunctions/diffeqf_20.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_21.c -o Cfunctions/diffeqf_21.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_22.c -o Cfunctions/diffeqf_22.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_23.c -o Cfunctions/diffeqf_23.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_24.c -o Cfunctions/diffeqf_24.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_25.c -o Cfunctions/diffeqf_25.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_26.c -o Cfunctions/diffeqf_26.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_27.c -o Cfunctions/diffeqf_27.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_28.c -o Cfunctions/diffeqf_28.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_29.c -o Cfunctions/diffeqf_29.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_3.c -o Cfunctions/diffeqf_3.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_30.c -o Cfunctions/diffeqf_30.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_31.c -o Cfunctions/diffeqf_31.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_32.c -o Cfunctions/diffeqf_32.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_33.c -o Cfunctions/diffeqf_33.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_34.c -o Cfunctions/diffeqf_34.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_35.c -o Cfunctions/diffeqf_35.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_36.c -o Cfunctions/diffeqf_36.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_37.c -o Cfunctions/diffeqf_37.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_38.c -o Cfunctions/diffeqf_38.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_39.c -o Cfunctions/diffeqf_39.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_4.c -o Cfunctions/diffeqf_4.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_40.c -o Cfunctions/diffeqf_40.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_41.c -o Cfunctions/diffeqf_41.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_42.c -o Cfunctions/diffeqf_42.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_43.c -o Cfunctions/diffeqf_43.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_44.c -o Cfunctions/diffeqf_44.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_45.c -o Cfunctions/diffeqf_45.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_46.c -o Cfunctions/diffeqf_46.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_47.c -o Cfunctions/diffeqf_47.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_48.c -o Cfunctions/diffeqf_48.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_49.c -o Cfunctions/diffeqf_49.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_5.c -o Cfunctions/diffeqf_5.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_50.c -o Cfunctions/diffeqf_50.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_51.c -o Cfunctions/diffeqf_51.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_52.c -o Cfunctions/diffeqf_52.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_53.c -o Cfunctions/diffeqf_53.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_54.c -o Cfunctions/diffeqf_54.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_55.c -o Cfunctions/diffeqf_55.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_56.c -o Cfunctions/diffeqf_56.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_57.c -o Cfunctions/diffeqf_57.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_58.c -o Cfunctions/diffeqf_58.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_59.c -o Cfunctions/diffeqf_59.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_6.c -o Cfunctions/diffeqf_6.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_60.c -o Cfunctions/diffeqf_60.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_61.c -o Cfunctions/diffeqf_61.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_62.c -o Cfunctions/diffeqf_62.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_63.c -o Cfunctions/diffeqf_63.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_64.c -o Cfunctions/diffeqf_64.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_65.c -o Cfunctions/diffeqf_65.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_66.c -o Cfunctions/diffeqf_66.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_67.c -o Cfunctions/diffeqf_67.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_68.c -o Cfunctions/diffeqf_68.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_69.c -o Cfunctions/diffeqf_69.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_7.c -o Cfunctions/diffeqf_7.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_70.c -o Cfunctions/diffeqf_70.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_71.c -o Cfunctions/diffeqf_71.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_72.c -o Cfunctions/diffeqf_72.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_73.c -o Cfunctions/diffeqf_73.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_74.c -o Cfunctions/diffeqf_74.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_75.c -o Cfunctions/diffeqf_75.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_76.c -o Cfunctions/diffeqf_76.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_77.c -o Cfunctions/diffeqf_77.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_78.c -o Cfunctions/diffeqf_78.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_79.c -o Cfunctions/diffeqf_79.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_8.c -o Cfunctions/diffeqf_8.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_80.c -o Cfunctions/diffeqf_80.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_81.c -o Cfunctions/diffeqf_81.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_82.c -o Cfunctions/diffeqf_82.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_83.c -o Cfunctions/diffeqf_83.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_84.c -o Cfunctions/diffeqf_84.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_85.c -o Cfunctions/diffeqf_85.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_86.c -o Cfunctions/diffeqf_86.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_87.c -o Cfunctions/diffeqf_87.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_9.c -o Cfunctions/diffeqf_9.o
# gcc -shared -o libs/liballfuncs_6.dll @objs.txt
# Progress:  20%|█████████                                |  ETA: 0:01:33
# gcc -fPIC -c -Wall -O3 dispatcher.c -o dispatcher.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_1.c -o Cfunctions/diffeqf_1.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_10.c -o Cfunctions/diffeqf_10.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_100.c -o Cfunctions/diffeqf_100.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_101.c -o Cfunctions/diffeqf_101.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_102.c -o Cfunctions/diffeqf_102.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_103.c -o Cfunctions/diffeqf_103.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_104.c -o Cfunctions/diffeqf_104.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_105.c -o Cfunctions/diffeqf_105.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_106.c -o Cfunctions/diffeqf_106.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_107.c -o Cfunctions/diffeqf_107.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_108.c -o Cfunctions/diffeqf_108.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_109.c -o Cfunctions/diffeqf_109.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_11.c -o Cfunctions/diffeqf_11.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_110.c -o Cfunctions/diffeqf_110.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_111.c -o Cfunctions/diffeqf_111.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_112.c -o Cfunctions/diffeqf_112.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_113.c -o Cfunctions/diffeqf_113.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_114.c -o Cfunctions/diffeqf_114.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_115.c -o Cfunctions/diffeqf_115.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_116.c -o Cfunctions/diffeqf_116.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_117.c -o Cfunctions/diffeqf_117.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_118.c -o Cfunctions/diffeqf_118.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_119.c -o Cfunctions/diffeqf_119.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_12.c -o Cfunctions/diffeqf_12.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_120.c -o Cfunctions/diffeqf_120.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_121.c -o Cfunctions/diffeqf_121.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_122.c -o Cfunctions/diffeqf_122.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_123.c -o Cfunctions/diffeqf_123.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_124.c -o Cfunctions/diffeqf_124.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_125.c -o Cfunctions/diffeqf_125.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_126.c -o Cfunctions/diffeqf_126.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_127.c -o Cfunctions/diffeqf_127.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_128.c -o Cfunctions/diffeqf_128.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_129.c -o Cfunctions/diffeqf_129.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_13.c -o Cfunctions/diffeqf_13.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_130.c -o Cfunctions/diffeqf_130.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_131.c -o Cfunctions/diffeqf_131.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_132.c -o Cfunctions/diffeqf_132.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_133.c -o Cfunctions/diffeqf_133.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_134.c -o Cfunctions/diffeqf_134.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_135.c -o Cfunctions/diffeqf_135.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_136.c -o Cfunctions/diffeqf_136.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_137.c -o Cfunctions/diffeqf_137.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_138.c -o Cfunctions/diffeqf_138.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_139.c -o Cfunctions/diffeqf_139.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_14.c -o Cfunctions/diffeqf_14.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_140.c -o Cfunctions/diffeqf_140.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_141.c -o Cfunctions/diffeqf_141.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_142.c -o Cfunctions/diffeqf_142.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_143.c -o Cfunctions/diffeqf_143.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_144.c -o Cfunctions/diffeqf_144.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_145.c -o Cfunctions/diffeqf_145.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_146.c -o Cfunctions/diffeqf_146.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_147.c -o Cfunctions/diffeqf_147.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_148.c -o Cfunctions/diffeqf_148.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_149.c -o Cfunctions/diffeqf_149.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_15.c -o Cfunctions/diffeqf_15.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_150.c -o Cfunctions/diffeqf_150.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_151.c -o Cfunctions/diffeqf_151.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_152.c -o Cfunctions/diffeqf_152.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_153.c -o Cfunctions/diffeqf_153.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_154.c -o Cfunctions/diffeqf_154.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_155.c -o Cfunctions/diffeqf_155.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_156.c -o Cfunctions/diffeqf_156.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_16.c -o Cfunctions/diffeqf_16.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_17.c -o Cfunctions/diffeqf_17.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_18.c -o Cfunctions/diffeqf_18.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_19.c -o Cfunctions/diffeqf_19.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_2.c -o Cfunctions/diffeqf_2.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_20.c -o Cfunctions/diffeqf_20.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_21.c -o Cfunctions/diffeqf_21.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_22.c -o Cfunctions/diffeqf_22.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_23.c -o Cfunctions/diffeqf_23.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_24.c -o Cfunctions/diffeqf_24.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_25.c -o Cfunctions/diffeqf_25.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_26.c -o Cfunctions/diffeqf_26.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_27.c -o Cfunctions/diffeqf_27.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_28.c -o Cfunctions/diffeqf_28.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_29.c -o Cfunctions/diffeqf_29.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_3.c -o Cfunctions/diffeqf_3.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_30.c -o Cfunctions/diffeqf_30.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_31.c -o Cfunctions/diffeqf_31.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_32.c -o Cfunctions/diffeqf_32.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_33.c -o Cfunctions/diffeqf_33.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_34.c -o Cfunctions/diffeqf_34.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_35.c -o Cfunctions/diffeqf_35.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_36.c -o Cfunctions/diffeqf_36.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_37.c -o Cfunctions/diffeqf_37.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_38.c -o Cfunctions/diffeqf_38.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_39.c -o Cfunctions/diffeqf_39.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_4.c -o Cfunctions/diffeqf_4.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_40.c -o Cfunctions/diffeqf_40.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_41.c -o Cfunctions/diffeqf_41.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_42.c -o Cfunctions/diffeqf_42.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_43.c -o Cfunctions/diffeqf_43.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_44.c -o Cfunctions/diffeqf_44.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_45.c -o Cfunctions/diffeqf_45.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_46.c -o Cfunctions/diffeqf_46.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_47.c -o Cfunctions/diffeqf_47.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_48.c -o Cfunctions/diffeqf_48.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_49.c -o Cfunctions/diffeqf_49.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_5.c -o Cfunctions/diffeqf_5.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_50.c -o Cfunctions/diffeqf_50.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_51.c -o Cfunctions/diffeqf_51.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_52.c -o Cfunctions/diffeqf_52.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_53.c -o Cfunctions/diffeqf_53.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_54.c -o Cfunctions/diffeqf_54.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_55.c -o Cfunctions/diffeqf_55.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_56.c -o Cfunctions/diffeqf_56.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_57.c -o Cfunctions/diffeqf_57.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_58.c -o Cfunctions/diffeqf_58.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_59.c -o Cfunctions/diffeqf_59.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_6.c -o Cfunctions/diffeqf_6.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_60.c -o Cfunctions/diffeqf_60.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_61.c -o Cfunctions/diffeqf_61.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_62.c -o Cfunctions/diffeqf_62.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_63.c -o Cfunctions/diffeqf_63.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_64.c -o Cfunctions/diffeqf_64.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_65.c -o Cfunctions/diffeqf_65.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_66.c -o Cfunctions/diffeqf_66.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_67.c -o Cfunctions/diffeqf_67.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_68.c -o Cfunctions/diffeqf_68.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_69.c -o Cfunctions/diffeqf_69.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_7.c -o Cfunctions/diffeqf_7.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_70.c -o Cfunctions/diffeqf_70.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_71.c -o Cfunctions/diffeqf_71.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_72.c -o Cfunctions/diffeqf_72.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_73.c -o Cfunctions/diffeqf_73.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_74.c -o Cfunctions/diffeqf_74.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_75.c -o Cfunctions/diffeqf_75.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_76.c -o Cfunctions/diffeqf_76.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_77.c -o Cfunctions/diffeqf_77.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_78.c -o Cfunctions/diffeqf_78.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_79.c -o Cfunctions/diffeqf_79.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_8.c -o Cfunctions/diffeqf_8.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_80.c -o Cfunctions/diffeqf_80.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_81.c -o Cfunctions/diffeqf_81.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_82.c -o Cfunctions/diffeqf_82.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_83.c -o Cfunctions/diffeqf_83.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_84.c -o Cfunctions/diffeqf_84.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_85.c -o Cfunctions/diffeqf_85.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_86.c -o Cfunctions/diffeqf_86.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_87.c -o Cfunctions/diffeqf_87.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_88.c -o Cfunctions/diffeqf_88.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_89.c -o Cfunctions/diffeqf_89.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_9.c -o Cfunctions/diffeqf_9.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_90.c -o Cfunctions/diffeqf_90.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_91.c -o Cfunctions/diffeqf_91.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_92.c -o Cfunctions/diffeqf_92.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_93.c -o Cfunctions/diffeqf_93.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_94.c -o Cfunctions/diffeqf_94.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_95.c -o Cfunctions/diffeqf_95.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_96.c -o Cfunctions/diffeqf_96.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_97.c -o Cfunctions/diffeqf_97.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_98.c -o Cfunctions/diffeqf_98.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_99.c -o Cfunctions/diffeqf_99.o
# gcc -shared -o libs/liballfuncs_8.dll @objs.txt
# Progress:  27%|███████████                              |  ETA: 0:02:44
# gcc -fPIC -c -Wall -O3 dispatcher.c -o dispatcher.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_1.c -o Cfunctions/diffeqf_1.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_10.c -o Cfunctions/diffeqf_10.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_100.c -o Cfunctions/diffeqf_100.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_101.c -o Cfunctions/diffeqf_101.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_102.c -o Cfunctions/diffeqf_102.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_103.c -o Cfunctions/diffeqf_103.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_104.c -o Cfunctions/diffeqf_104.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_105.c -o Cfunctions/diffeqf_105.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_106.c -o Cfunctions/diffeqf_106.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_107.c -o Cfunctions/diffeqf_107.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_108.c -o Cfunctions/diffeqf_108.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_109.c -o Cfunctions/diffeqf_109.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_11.c -o Cfunctions/diffeqf_11.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_110.c -o Cfunctions/diffeqf_110.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_111.c -o Cfunctions/diffeqf_111.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_112.c -o Cfunctions/diffeqf_112.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_113.c -o Cfunctions/diffeqf_113.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_114.c -o Cfunctions/diffeqf_114.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_115.c -o Cfunctions/diffeqf_115.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_116.c -o Cfunctions/diffeqf_116.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_117.c -o Cfunctions/diffeqf_117.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_118.c -o Cfunctions/diffeqf_118.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_119.c -o Cfunctions/diffeqf_119.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_12.c -o Cfunctions/diffeqf_12.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_120.c -o Cfunctions/diffeqf_120.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_121.c -o Cfunctions/diffeqf_121.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_122.c -o Cfunctions/diffeqf_122.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_123.c -o Cfunctions/diffeqf_123.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_124.c -o Cfunctions/diffeqf_124.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_125.c -o Cfunctions/diffeqf_125.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_126.c -o Cfunctions/diffeqf_126.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_127.c -o Cfunctions/diffeqf_127.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_128.c -o Cfunctions/diffeqf_128.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_129.c -o Cfunctions/diffeqf_129.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_13.c -o Cfunctions/diffeqf_13.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_130.c -o Cfunctions/diffeqf_130.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_131.c -o Cfunctions/diffeqf_131.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_132.c -o Cfunctions/diffeqf_132.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_133.c -o Cfunctions/diffeqf_133.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_134.c -o Cfunctions/diffeqf_134.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_135.c -o Cfunctions/diffeqf_135.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_136.c -o Cfunctions/diffeqf_136.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_137.c -o Cfunctions/diffeqf_137.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_138.c -o Cfunctions/diffeqf_138.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_139.c -o Cfunctions/diffeqf_139.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_14.c -o Cfunctions/diffeqf_14.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_140.c -o Cfunctions/diffeqf_140.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_141.c -o Cfunctions/diffeqf_141.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_142.c -o Cfunctions/diffeqf_142.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_143.c -o Cfunctions/diffeqf_143.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_144.c -o Cfunctions/diffeqf_144.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_145.c -o Cfunctions/diffeqf_145.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_146.c -o Cfunctions/diffeqf_146.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_147.c -o Cfunctions/diffeqf_147.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_148.c -o Cfunctions/diffeqf_148.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_149.c -o Cfunctions/diffeqf_149.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_15.c -o Cfunctions/diffeqf_15.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_150.c -o Cfunctions/diffeqf_150.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_151.c -o Cfunctions/diffeqf_151.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_152.c -o Cfunctions/diffeqf_152.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_153.c -o Cfunctions/diffeqf_153.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_154.c -o Cfunctions/diffeqf_154.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_155.c -o Cfunctions/diffeqf_155.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_156.c -o Cfunctions/diffeqf_156.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_157.c -o Cfunctions/diffeqf_157.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_158.c -o Cfunctions/diffeqf_158.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_159.c -o Cfunctions/diffeqf_159.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_16.c -o Cfunctions/diffeqf_16.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_160.c -o Cfunctions/diffeqf_160.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_161.c -o Cfunctions/diffeqf_161.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_162.c -o Cfunctions/diffeqf_162.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_163.c -o Cfunctions/diffeqf_163.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_164.c -o Cfunctions/diffeqf_164.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_165.c -o Cfunctions/diffeqf_165.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_166.c -o Cfunctions/diffeqf_166.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_167.c -o Cfunctions/diffeqf_167.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_168.c -o Cfunctions/diffeqf_168.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_169.c -o Cfunctions/diffeqf_169.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_17.c -o Cfunctions/diffeqf_17.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_170.c -o Cfunctions/diffeqf_170.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_171.c -o Cfunctions/diffeqf_171.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_172.c -o Cfunctions/diffeqf_172.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_173.c -o Cfunctions/diffeqf_173.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_174.c -o Cfunctions/diffeqf_174.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_175.c -o Cfunctions/diffeqf_175.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_176.c -o Cfunctions/diffeqf_176.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_177.c -o Cfunctions/diffeqf_177.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_178.c -o Cfunctions/diffeqf_178.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_179.c -o Cfunctions/diffeqf_179.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_18.c -o Cfunctions/diffeqf_18.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_180.c -o Cfunctions/diffeqf_180.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_181.c -o Cfunctions/diffeqf_181.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_182.c -o Cfunctions/diffeqf_182.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_183.c -o Cfunctions/diffeqf_183.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_184.c -o Cfunctions/diffeqf_184.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_185.c -o Cfunctions/diffeqf_185.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_186.c -o Cfunctions/diffeqf_186.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_187.c -o Cfunctions/diffeqf_187.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_188.c -o Cfunctions/diffeqf_188.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_189.c -o Cfunctions/diffeqf_189.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_19.c -o Cfunctions/diffeqf_19.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_190.c -o Cfunctions/diffeqf_190.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_191.c -o Cfunctions/diffeqf_191.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_192.c -o Cfunctions/diffeqf_192.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_193.c -o Cfunctions/diffeqf_193.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_194.c -o Cfunctions/diffeqf_194.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_195.c -o Cfunctions/diffeqf_195.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_196.c -o Cfunctions/diffeqf_196.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_197.c -o Cfunctions/diffeqf_197.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_198.c -o Cfunctions/diffeqf_198.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_199.c -o Cfunctions/diffeqf_199.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_2.c -o Cfunctions/diffeqf_2.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_20.c -o Cfunctions/diffeqf_20.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_200.c -o Cfunctions/diffeqf_200.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_201.c -o Cfunctions/diffeqf_201.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_202.c -o Cfunctions/diffeqf_202.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_203.c -o Cfunctions/diffeqf_203.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_204.c -o Cfunctions/diffeqf_204.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_205.c -o Cfunctions/diffeqf_205.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_206.c -o Cfunctions/diffeqf_206.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_207.c -o Cfunctions/diffeqf_207.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_208.c -o Cfunctions/diffeqf_208.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_209.c -o Cfunctions/diffeqf_209.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_21.c -o Cfunctions/diffeqf_21.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_210.c -o Cfunctions/diffeqf_210.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_211.c -o Cfunctions/diffeqf_211.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_212.c -o Cfunctions/diffeqf_212.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_213.c -o Cfunctions/diffeqf_213.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_214.c -o Cfunctions/diffeqf_214.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_215.c -o Cfunctions/diffeqf_215.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_216.c -o Cfunctions/diffeqf_216.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_217.c -o Cfunctions/diffeqf_217.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_218.c -o Cfunctions/diffeqf_218.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_219.c -o Cfunctions/diffeqf_219.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_22.c -o Cfunctions/diffeqf_22.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_220.c -o Cfunctions/diffeqf_220.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_221.c -o Cfunctions/diffeqf_221.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_222.c -o Cfunctions/diffeqf_222.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_223.c -o Cfunctions/diffeqf_223.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_224.c -o Cfunctions/diffeqf_224.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_225.c -o Cfunctions/diffeqf_225.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_226.c -o Cfunctions/diffeqf_226.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_227.c -o Cfunctions/diffeqf_227.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_228.c -o Cfunctions/diffeqf_228.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_229.c -o Cfunctions/diffeqf_229.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_23.c -o Cfunctions/diffeqf_23.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_230.c -o Cfunctions/diffeqf_230.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_231.c -o Cfunctions/diffeqf_231.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_232.c -o Cfunctions/diffeqf_232.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_233.c -o Cfunctions/diffeqf_233.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_234.c -o Cfunctions/diffeqf_234.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_235.c -o Cfunctions/diffeqf_235.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_236.c -o Cfunctions/diffeqf_236.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_237.c -o Cfunctions/diffeqf_237.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_238.c -o Cfunctions/diffeqf_238.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_239.c -o Cfunctions/diffeqf_239.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_24.c -o Cfunctions/diffeqf_24.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_240.c -o Cfunctions/diffeqf_240.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_241.c -o Cfunctions/diffeqf_241.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_242.c -o Cfunctions/diffeqf_242.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_243.c -o Cfunctions/diffeqf_243.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_244.c -o Cfunctions/diffeqf_244.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_245.c -o Cfunctions/diffeqf_245.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_25.c -o Cfunctions/diffeqf_25.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_26.c -o Cfunctions/diffeqf_26.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_27.c -o Cfunctions/diffeqf_27.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_28.c -o Cfunctions/diffeqf_28.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_29.c -o Cfunctions/diffeqf_29.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_3.c -o Cfunctions/diffeqf_3.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_30.c -o Cfunctions/diffeqf_30.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_31.c -o Cfunctions/diffeqf_31.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_32.c -o Cfunctions/diffeqf_32.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_33.c -o Cfunctions/diffeqf_33.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_34.c -o Cfunctions/diffeqf_34.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_35.c -o Cfunctions/diffeqf_35.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_36.c -o Cfunctions/diffeqf_36.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_37.c -o Cfunctions/diffeqf_37.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_38.c -o Cfunctions/diffeqf_38.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_39.c -o Cfunctions/diffeqf_39.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_4.c -o Cfunctions/diffeqf_4.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_40.c -o Cfunctions/diffeqf_40.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_41.c -o Cfunctions/diffeqf_41.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_42.c -o Cfunctions/diffeqf_42.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_43.c -o Cfunctions/diffeqf_43.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_44.c -o Cfunctions/diffeqf_44.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_45.c -o Cfunctions/diffeqf_45.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_46.c -o Cfunctions/diffeqf_46.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_47.c -o Cfunctions/diffeqf_47.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_48.c -o Cfunctions/diffeqf_48.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_49.c -o Cfunctions/diffeqf_49.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_5.c -o Cfunctions/diffeqf_5.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_50.c -o Cfunctions/diffeqf_50.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_51.c -o Cfunctions/diffeqf_51.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_52.c -o Cfunctions/diffeqf_52.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_53.c -o Cfunctions/diffeqf_53.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_54.c -o Cfunctions/diffeqf_54.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_55.c -o Cfunctions/diffeqf_55.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_56.c -o Cfunctions/diffeqf_56.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_57.c -o Cfunctions/diffeqf_57.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_58.c -o Cfunctions/diffeqf_58.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_59.c -o Cfunctions/diffeqf_59.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_6.c -o Cfunctions/diffeqf_6.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_60.c -o Cfunctions/diffeqf_60.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_61.c -o Cfunctions/diffeqf_61.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_62.c -o Cfunctions/diffeqf_62.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_63.c -o Cfunctions/diffeqf_63.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_64.c -o Cfunctions/diffeqf_64.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_65.c -o Cfunctions/diffeqf_65.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_66.c -o Cfunctions/diffeqf_66.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_67.c -o Cfunctions/diffeqf_67.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_68.c -o Cfunctions/diffeqf_68.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_69.c -o Cfunctions/diffeqf_69.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_7.c -o Cfunctions/diffeqf_7.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_70.c -o Cfunctions/diffeqf_70.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_71.c -o Cfunctions/diffeqf_71.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_72.c -o Cfunctions/diffeqf_72.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_73.c -o Cfunctions/diffeqf_73.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_74.c -o Cfunctions/diffeqf_74.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_75.c -o Cfunctions/diffeqf_75.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_76.c -o Cfunctions/diffeqf_76.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_77.c -o Cfunctions/diffeqf_77.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_78.c -o Cfunctions/diffeqf_78.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_79.c -o Cfunctions/diffeqf_79.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_8.c -o Cfunctions/diffeqf_8.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_80.c -o Cfunctions/diffeqf_80.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_81.c -o Cfunctions/diffeqf_81.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_82.c -o Cfunctions/diffeqf_82.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_83.c -o Cfunctions/diffeqf_83.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_84.c -o Cfunctions/diffeqf_84.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_85.c -o Cfunctions/diffeqf_85.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_86.c -o Cfunctions/diffeqf_86.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_87.c -o Cfunctions/diffeqf_87.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_88.c -o Cfunctions/diffeqf_88.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_89.c -o Cfunctions/diffeqf_89.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_9.c -o Cfunctions/diffeqf_9.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_90.c -o Cfunctions/diffeqf_90.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_91.c -o Cfunctions/diffeqf_91.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_92.c -o Cfunctions/diffeqf_92.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_93.c -o Cfunctions/diffeqf_93.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_94.c -o Cfunctions/diffeqf_94.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_95.c -o Cfunctions/diffeqf_95.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_96.c -o Cfunctions/diffeqf_96.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_97.c -o Cfunctions/diffeqf_97.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_98.c -o Cfunctions/diffeqf_98.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_99.c -o Cfunctions/diffeqf_99.o
# gcc -shared -o libs/liballfuncs_10.dll @objs.txt
# Progress:  33%|██████████████                           |  ETA: 0:04:36
# gcc -fPIC -c -Wall -O3 dispatcher.c -o dispatcher.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_1.c -o Cfunctions/diffeqf_1.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_10.c -o Cfunctions/diffeqf_10.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_100.c -o Cfunctions/diffeqf_100.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_101.c -o Cfunctions/diffeqf_101.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_102.c -o Cfunctions/diffeqf_102.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_103.c -o Cfunctions/diffeqf_103.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_104.c -o Cfunctions/diffeqf_104.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_105.c -o Cfunctions/diffeqf_105.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_106.c -o Cfunctions/diffeqf_106.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_107.c -o Cfunctions/diffeqf_107.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_108.c -o Cfunctions/diffeqf_108.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_109.c -o Cfunctions/diffeqf_109.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_11.c -o Cfunctions/diffeqf_11.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_110.c -o Cfunctions/diffeqf_110.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_111.c -o Cfunctions/diffeqf_111.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_112.c -o Cfunctions/diffeqf_112.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_113.c -o Cfunctions/diffeqf_113.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_114.c -o Cfunctions/diffeqf_114.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_115.c -o Cfunctions/diffeqf_115.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_116.c -o Cfunctions/diffeqf_116.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_117.c -o Cfunctions/diffeqf_117.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_118.c -o Cfunctions/diffeqf_118.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_119.c -o Cfunctions/diffeqf_119.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_12.c -o Cfunctions/diffeqf_12.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_120.c -o Cfunctions/diffeqf_120.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_121.c -o Cfunctions/diffeqf_121.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_122.c -o Cfunctions/diffeqf_122.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_123.c -o Cfunctions/diffeqf_123.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_124.c -o Cfunctions/diffeqf_124.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_125.c -o Cfunctions/diffeqf_125.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_126.c -o Cfunctions/diffeqf_126.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_127.c -o Cfunctions/diffeqf_127.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_128.c -o Cfunctions/diffeqf_128.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_129.c -o Cfunctions/diffeqf_129.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_13.c -o Cfunctions/diffeqf_13.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_130.c -o Cfunctions/diffeqf_130.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_131.c -o Cfunctions/diffeqf_131.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_132.c -o Cfunctions/diffeqf_132.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_133.c -o Cfunctions/diffeqf_133.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_134.c -o Cfunctions/diffeqf_134.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_135.c -o Cfunctions/diffeqf_135.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_136.c -o Cfunctions/diffeqf_136.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_137.c -o Cfunctions/diffeqf_137.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_138.c -o Cfunctions/diffeqf_138.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_139.c -o Cfunctions/diffeqf_139.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_14.c -o Cfunctions/diffeqf_14.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_140.c -o Cfunctions/diffeqf_140.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_141.c -o Cfunctions/diffeqf_141.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_142.c -o Cfunctions/diffeqf_142.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_143.c -o Cfunctions/diffeqf_143.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_144.c -o Cfunctions/diffeqf_144.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_145.c -o Cfunctions/diffeqf_145.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_146.c -o Cfunctions/diffeqf_146.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_147.c -o Cfunctions/diffeqf_147.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_148.c -o Cfunctions/diffeqf_148.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_149.c -o Cfunctions/diffeqf_149.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_15.c -o Cfunctions/diffeqf_15.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_150.c -o Cfunctions/diffeqf_150.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_151.c -o Cfunctions/diffeqf_151.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_152.c -o Cfunctions/diffeqf_152.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_153.c -o Cfunctions/diffeqf_153.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_154.c -o Cfunctions/diffeqf_154.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_155.c -o Cfunctions/diffeqf_155.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_156.c -o Cfunctions/diffeqf_156.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_157.c -o Cfunctions/diffeqf_157.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_158.c -o Cfunctions/diffeqf_158.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_159.c -o Cfunctions/diffeqf_159.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_16.c -o Cfunctions/diffeqf_16.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_160.c -o Cfunctions/diffeqf_160.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_161.c -o Cfunctions/diffeqf_161.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_162.c -o Cfunctions/diffeqf_162.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_163.c -o Cfunctions/diffeqf_163.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_164.c -o Cfunctions/diffeqf_164.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_165.c -o Cfunctions/diffeqf_165.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_166.c -o Cfunctions/diffeqf_166.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_167.c -o Cfunctions/diffeqf_167.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_168.c -o Cfunctions/diffeqf_168.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_169.c -o Cfunctions/diffeqf_169.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_17.c -o Cfunctions/diffeqf_17.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_170.c -o Cfunctions/diffeqf_170.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_171.c -o Cfunctions/diffeqf_171.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_172.c -o Cfunctions/diffeqf_172.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_173.c -o Cfunctions/diffeqf_173.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_174.c -o Cfunctions/diffeqf_174.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_175.c -o Cfunctions/diffeqf_175.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_176.c -o Cfunctions/diffeqf_176.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_177.c -o Cfunctions/diffeqf_177.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_178.c -o Cfunctions/diffeqf_178.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_179.c -o Cfunctions/diffeqf_179.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_18.c -o Cfunctions/diffeqf_18.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_180.c -o Cfunctions/diffeqf_180.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_181.c -o Cfunctions/diffeqf_181.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_182.c -o Cfunctions/diffeqf_182.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_183.c -o Cfunctions/diffeqf_183.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_184.c -o Cfunctions/diffeqf_184.o
# ...
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_810.c -o Cfunctions/diffeqf_810.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_811.c -o Cfunctions/diffeqf_811.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_812.c -o Cfunctions/diffeqf_812.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_813.c -o Cfunctions/diffeqf_813.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_814.c -o Cfunctions/diffeqf_814.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_815.c -o Cfunctions/diffeqf_815.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_816.c -o Cfunctions/diffeqf_816.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_817.c -o Cfunctions/diffeqf_817.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_818.c -o Cfunctions/diffeqf_818.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_819.c -o Cfunctions/diffeqf_819.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_82.c -o Cfunctions/diffeqf_82.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_820.c -o Cfunctions/diffeqf_820.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_821.c -o Cfunctions/diffeqf_821.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_822.c -o Cfunctions/diffeqf_822.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_823.c -o Cfunctions/diffeqf_823.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_824.c -o Cfunctions/diffeqf_824.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_825.c -o Cfunctions/diffeqf_825.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_826.c -o Cfunctions/diffeqf_826.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_827.c -o Cfunctions/diffeqf_827.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_828.c -o Cfunctions/diffeqf_828.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_829.c -o Cfunctions/diffeqf_829.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_83.c -o Cfunctions/diffeqf_83.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_830.c -o Cfunctions/diffeqf_830.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_831.c -o Cfunctions/diffeqf_831.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_832.c -o Cfunctions/diffeqf_832.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_833.c -o Cfunctions/diffeqf_833.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_834.c -o Cfunctions/diffeqf_834.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_835.c -o Cfunctions/diffeqf_835.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_836.c -o Cfunctions/diffeqf_836.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_837.c -o Cfunctions/diffeqf_837.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_838.c -o Cfunctions/diffeqf_838.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_839.c -o Cfunctions/diffeqf_839.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_84.c -o Cfunctions/diffeqf_84.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_840.c -o Cfunctions/diffeqf_840.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_841.c -o Cfunctions/diffeqf_841.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_842.c -o Cfunctions/diffeqf_842.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_843.c -o Cfunctions/diffeqf_843.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_844.c -o Cfunctions/diffeqf_844.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_845.c -o Cfunctions/diffeqf_845.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_846.c -o Cfunctions/diffeqf_846.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_847.c -o Cfunctions/diffeqf_847.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_848.c -o Cfunctions/diffeqf_848.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_849.c -o Cfunctions/diffeqf_849.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_85.c -o Cfunctions/diffeqf_85.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_850.c -o Cfunctions/diffeqf_850.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_851.c -o Cfunctions/diffeqf_851.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_852.c -o Cfunctions/diffeqf_852.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_853.c -o Cfunctions/diffeqf_853.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_854.c -o Cfunctions/diffeqf_854.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_855.c -o Cfunctions/diffeqf_855.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_856.c -o Cfunctions/diffeqf_856.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_857.c -o Cfunctions/diffeqf_857.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_858.c -o Cfunctions/diffeqf_858.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_859.c -o Cfunctions/diffeqf_859.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_86.c -o Cfunctions/diffeqf_86.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_860.c -o Cfunctions/diffeqf_860.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_861.c -o Cfunctions/diffeqf_861.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_862.c -o Cfunctions/diffeqf_862.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_863.c -o Cfunctions/diffeqf_863.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_864.c -o Cfunctions/diffeqf_864.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_865.c -o Cfunctions/diffeqf_865.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_866.c -o Cfunctions/diffeqf_866.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_867.c -o Cfunctions/diffeqf_867.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_868.c -o Cfunctions/diffeqf_868.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_869.c -o Cfunctions/diffeqf_869.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_87.c -o Cfunctions/diffeqf_87.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_870.c -o Cfunctions/diffeqf_870.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_871.c -o Cfunctions/diffeqf_871.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_872.c -o Cfunctions/diffeqf_872.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_873.c -o Cfunctions/diffeqf_873.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_874.c -o Cfunctions/diffeqf_874.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_875.c -o Cfunctions/diffeqf_875.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_876.c -o Cfunctions/diffeqf_876.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_877.c -o Cfunctions/diffeqf_877.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_878.c -o Cfunctions/diffeqf_878.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_879.c -o Cfunctions/diffeqf_879.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_88.c -o Cfunctions/diffeqf_88.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_880.c -o Cfunctions/diffeqf_880.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_881.c -o Cfunctions/diffeqf_881.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_882.c -o Cfunctions/diffeqf_882.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_883.c -o Cfunctions/diffeqf_883.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_884.c -o Cfunctions/diffeqf_884.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_885.c -o Cfunctions/diffeqf_885.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_886.c -o Cfunctions/diffeqf_886.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_887.c -o Cfunctions/diffeqf_887.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_888.c -o Cfunctions/diffeqf_888.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_889.c -o Cfunctions/diffeqf_889.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_89.c -o Cfunctions/diffeqf_89.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_890.c -o Cfunctions/diffeqf_890.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_891.c -o Cfunctions/diffeqf_891.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_892.c -o Cfunctions/diffeqf_892.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_893.c -o Cfunctions/diffeqf_893.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_894.c -o Cfunctions/diffeqf_894.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_895.c -o Cfunctions/diffeqf_895.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_896.c -o Cfunctions/diffeqf_896.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_897.c -o Cfunctions/diffeqf_897.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_898.c -o Cfunctions/diffeqf_898.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_899.c -o Cfunctions/diffeqf_899.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_9.c -o Cfunctions/diffeqf_9.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_90.c -o Cfunctions/diffeqf_90.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_900.c -o Cfunctions/diffeqf_900.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_901.c -o Cfunctions/diffeqf_901.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_902.c -o Cfunctions/diffeqf_902.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_903.c -o Cfunctions/diffeqf_903.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_904.c -o Cfunctions/diffeqf_904.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_905.c -o Cfunctions/diffeqf_905.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_906.c -o Cfunctions/diffeqf_906.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_907.c -o Cfunctions/diffeqf_907.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_908.c -o Cfunctions/diffeqf_908.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_909.c -o Cfunctions/diffeqf_909.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_91.c -o Cfunctions/diffeqf_91.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_910.c -o Cfunctions/diffeqf_910.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_911.c -o Cfunctions/diffeqf_911.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_912.c -o Cfunctions/diffeqf_912.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_913.c -o Cfunctions/diffeqf_913.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_914.c -o Cfunctions/diffeqf_914.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_915.c -o Cfunctions/diffeqf_915.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_916.c -o Cfunctions/diffeqf_916.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_917.c -o Cfunctions/diffeqf_917.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_918.c -o Cfunctions/diffeqf_918.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_919.c -o Cfunctions/diffeqf_919.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_92.c -o Cfunctions/diffeqf_92.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_920.c -o Cfunctions/diffeqf_920.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_921.c -o Cfunctions/diffeqf_921.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_922.c -o Cfunctions/diffeqf_922.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_923.c -o Cfunctions/diffeqf_923.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_924.c -o Cfunctions/diffeqf_924.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_925.c -o Cfunctions/diffeqf_925.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_926.c -o Cfunctions/diffeqf_926.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_927.c -o Cfunctions/diffeqf_927.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_928.c -o Cfunctions/diffeqf_928.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_929.c -o Cfunctions/diffeqf_929.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_93.c -o Cfunctions/diffeqf_93.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_930.c -o Cfunctions/diffeqf_930.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_931.c -o Cfunctions/diffeqf_931.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_932.c -o Cfunctions/diffeqf_932.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_933.c -o Cfunctions/diffeqf_933.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_934.c -o Cfunctions/diffeqf_934.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_935.c -o Cfunctions/diffeqf_935.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_936.c -o Cfunctions/diffeqf_936.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_937.c -o Cfunctions/diffeqf_937.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_938.c -o Cfunctions/diffeqf_938.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_939.c -o Cfunctions/diffeqf_939.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_94.c -o Cfunctions/diffeqf_94.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_940.c -o Cfunctions/diffeqf_940.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_941.c -o Cfunctions/diffeqf_941.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_942.c -o Cfunctions/diffeqf_942.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_943.c -o Cfunctions/diffeqf_943.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_944.c -o Cfunctions/diffeqf_944.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_945.c -o Cfunctions/diffeqf_945.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_946.c -o Cfunctions/diffeqf_946.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_947.c -o Cfunctions/diffeqf_947.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_948.c -o Cfunctions/diffeqf_948.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_949.c -o Cfunctions/diffeqf_949.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_95.c -o Cfunctions/diffeqf_95.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_950.c -o Cfunctions/diffeqf_950.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_951.c -o Cfunctions/diffeqf_951.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_952.c -o Cfunctions/diffeqf_952.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_953.c -o Cfunctions/diffeqf_953.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_954.c -o Cfunctions/diffeqf_954.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_955.c -o Cfunctions/diffeqf_955.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_956.c -o Cfunctions/diffeqf_956.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_957.c -o Cfunctions/diffeqf_957.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_958.c -o Cfunctions/diffeqf_958.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_959.c -o Cfunctions/diffeqf_959.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_96.c -o Cfunctions/diffeqf_96.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_960.c -o Cfunctions/diffeqf_960.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_961.c -o Cfunctions/diffeqf_961.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_962.c -o Cfunctions/diffeqf_962.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_963.c -o Cfunctions/diffeqf_963.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_964.c -o Cfunctions/diffeqf_964.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_965.c -o Cfunctions/diffeqf_965.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_966.c -o Cfunctions/diffeqf_966.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_967.c -o Cfunctions/diffeqf_967.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_968.c -o Cfunctions/diffeqf_968.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_969.c -o Cfunctions/diffeqf_969.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_97.c -o Cfunctions/diffeqf_97.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_970.c -o Cfunctions/diffeqf_970.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_971.c -o Cfunctions/diffeqf_971.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_972.c -o Cfunctions/diffeqf_972.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_973.c -o Cfunctions/diffeqf_973.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_974.c -o Cfunctions/diffeqf_974.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_975.c -o Cfunctions/diffeqf_975.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_976.c -o Cfunctions/diffeqf_976.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_977.c -o Cfunctions/diffeqf_977.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_978.c -o Cfunctions/diffeqf_978.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_979.c -o Cfunctions/diffeqf_979.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_98.c -o Cfunctions/diffeqf_98.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_980.c -o Cfunctions/diffeqf_980.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_981.c -o Cfunctions/diffeqf_981.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_982.c -o Cfunctions/diffeqf_982.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_983.c -o Cfunctions/diffeqf_983.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_984.c -o Cfunctions/diffeqf_984.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_985.c -o Cfunctions/diffeqf_985.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_986.c -o Cfunctions/diffeqf_986.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_987.c -o Cfunctions/diffeqf_987.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_988.c -o Cfunctions/diffeqf_988.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_989.c -o Cfunctions/diffeqf_989.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_99.c -o Cfunctions/diffeqf_99.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_990.c -o Cfunctions/diffeqf_990.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_991.c -o Cfunctions/diffeqf_991.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_992.c -o Cfunctions/diffeqf_992.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_993.c -o Cfunctions/diffeqf_993.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_994.c -o Cfunctions/diffeqf_994.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_995.c -o Cfunctions/diffeqf_995.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_996.c -o Cfunctions/diffeqf_996.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_997.c -o Cfunctions/diffeqf_997.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_998.c -o Cfunctions/diffeqf_998.o
# gcc -fPIC -c -Wall -O3 Cfunctions/diffeqf_999.c -o Cfunctions/diffeqf_999.o
# gcc -shared -o libs/liballfuncs_30.dll @objs.txt
# Progress: 100%|█████████████████████████████████████████| Time: 5:10:21
