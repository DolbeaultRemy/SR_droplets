# %%
include("MiniCollectiveSpins.jl")
using PyPlot
using Statistics
using JLD2
using ProgressBars

# %% [markdown]
# ### Define the system

# %%
# Parameters
N = 10
sat = vcat([0.1:0.1:0.9;], [1:34;]) # [1:35;] #[0.1:5:35.1;]
pathname_density_distrib = "Groundstate_Bext_90_deg_as_98.h5"
@load "Density_distributions\\$(pathname_density_distrib[1:end-3]).jld2" CS_densities_cuts_norm
n_list = CS_densities_cuts_norm * 3 # List of density to simulate. Multiply by 3 if 10 atoms simulated instead of 30 atoms
# n_list = CS_densities_cuts_norm[1:100:length(CS_densities_cuts_norm)]
# Quantization axis along z
e = [0, 0, 1.]

# Constants
λ = 421e-9
γ = 32.7e6 # In Hz
@load "op_list/op_list_$N.jdl2" op_list;

# %%
println("Nbr of Atoms simulated = $(sum(n_list)*(0.1882352941176464/421e-3)^2*0.3809523809523814/421e-3)")

# %% [markdown]
# ### Recover data from simulations

# %%
list_t_N, popup_t_N, sol_t_N, nbr_error_N = [], [], [], []

for (i, s) in ProgressBar(enumerate(sat))
    line = []
    @load "solutions/Old_versions/sol_N_$(N)_sat_$(sat[i])_stripe_distribution_$(pathname_density_distrib[1:end-3]).jld2" N n_list sat sol_tasks
    list_t, popup_t, sol_t =  [vcat([st[i] for st in sol_tasks]...) for i = 1:3]
    push!(list_t_N, list_t), push!(popup_t_N, popup_t), push!(sol_t_N, sol_t), push!(nbr_error_N, sum(vcat([st[4] for st in sol_tasks]...)))
end

# %% [markdown]
# # Plots of the time evolution

# %%
close("all")
fig, ax = subplots()

for (i, s) in ProgressBar(enumerate(sat))
    line = []
    for j in 1:length(popup_t_N[i])
        if line == []
            line, = ax.plot(list_t_N[i][j], popup_t_N[i][j] / N, label="Sat=$(s)")
        else
            ax.plot(list_t_N[i][j], popup_t_N[i][j] / N, color=line.get_color()) # marker="o", markersize=1,
        end
    end
end

ax.set_xlabel(L"$\gamma t$")
ax.set_ylabel(L"$\langle  n_{\uparrow} \rangle $")
ax.legend()

suptitle("Stripe simulation, starting from "*L"$|\downarrow \downarrow \rangle $")
pygui(false); gcf();
# pygui(true); show()

# %% [markdown]
# ### Density dependancy

# %%
close("all")
fig, ax = subplots()

i = 5 #length(sat) # Saturation intensity

line = []
for j in 1:1:length(popup_t_N[i])
    line, = ax.plot(list_t_N[i][j], popup_t_N[i][j] / N, label="n0=$(round(n_list[j]))")
end


ax.set_xlabel(L"$\gamma t$")
ax.set_ylabel(L"$\langle  n_{\uparrow} \rangle $")
ax.legend()

suptitle("Stripe simulation, starting from "*L"$|\downarrow \downarrow \rangle $"*", Sat=$(sat[i])")
pygui(false); gcf();
# pygui(true); show()

# %% [markdown]
# # Mean of the SS

# %%
sat = vcat([0.1:0.1:0.9;], [1:34;]); # [1:35;] #[0.1:5:35.1;]

# %%
mean_SS = mean.([[popup_t_N[i][j][end] for j = 1:length(popup_t_N[i])] for i = 1:length(popup_t_N)])
std_SS = std.([[popup_t_N[i][j][end] for j = 1:length(popup_t_N[i])] for i = 1:length(popup_t_N)])

fig, axes = subplots(1, 2, figsize = (15, 5))
axes[1].errorbar(sat, mean_SS, yerr=std_SS ./ sqrt.([length(popup_t_N[i]) for i = 1:length(sat)]))
axes[1].set_xlabel(L"s")
axes[1].set_ylabel(L"$\langle  N_{\uparrow}^{SS} \rangle $")

axes[2].errorbar(sat, mean_SS./N, yerr=std_SS ./ (N .* sqrt.([length(popup_t_N[i]) for i = 1:length(sat)])))
axes[2].set_xlabel(L"s")
axes[2].set_ylabel(L"$\langle  n_{\uparrow}^{SS} \rangle $")

suptitle("Starting from "*L"$|\downarrow \downarrow \rangle $")

pygui(false); gcf();
# pygui(true); show()

# %% [markdown]
# # Compute $\gamma_{SE}$ from the SR SS

# %%
I_SE_SR_SS = zeros(ComplexF64, (length(sat), length(n_list)))

for (i, s) in enumerate(sat)
    for j in 1:length(n_list)
        
        if length(sol_t_N[i][j][end]) > 1 # If the full solution yas saved
            sol_SS = sol_t_N[i][j][end]
        else
            sol_SS = sol_t_N[i][j] # Only the SS was saved
        end

        for a = 1:N
            I_SE_SR_SS[i, j] += sol_SS[a] # The decay rates are normalized by γ
        end
    end
end
I_SE_SR_SS = real.(I_SE_SR_SS); # This is the mean decay rate of SE in the full stripe

# %% [markdown]
# # Compute $\gamma_{SR}$ from the SR SS

# %%
I_SR_SR_SS = zeros(ComplexF64, (length(sat), length(n_list)))

for (i, s) in ProgressBar(enumerate(sat))
    for j in 1:length(n_list)
        @load "r0/Old_versions/r0_N_$(N)_density_nbr_$(j)_sat_$(round(sat[i], digits=1)).jdl2" r0 L
        system = SpinCollection(r0, e, gammas=1.)
        Γ_CS = GammaMatrix(system)
        
        if length(sol_t_N[i][j][end]) > 1 # If the full solution yas saved
            sol_SS = sol_t_N[i][j][end]
        else
            sol_SS = sol_t_N[i][j] # Only the SS was saved
        end

        for a = 1:N
            for b = 1:N
                if b > a # Correlated decay
                    corr = [21*10^(floor(Int, log10(a))+1)+a, 12*10^(floor(Int, log10(b))+1)+b]
                    try
                        I_SR_SR_SS[i, j] += 2*Γ_CS[a, b]*sol_SS[findall(x->x==corr || x==reverse(corr), op_list)[1]]
                    catch
                        println("Error @ $N, r=$j, a=$a, b=$b, corr=$corr")
                    end
                end
            end
        end
    end
end
I_SR_SR_SS = real.(I_SR_SR_SS); # This is the mean decay rate of SR in the full stripe

# %%
Itot = I_SE_SR_SS .+ I_SR_SR_SS;

# %%
close("all")
fig = subplots()

plot(sat, sum(I_SE_SR_SS, dims=2), label="SE from SR SS")
plot(sat, sum(I_SR_SR_SS, dims=2), label="Collective decay from SR SS")
plot(sat, sum(Itot, dims=2), label="Sum of the decays")

xlabel(L"s")
ylabel(L"$I$")

suptitle("Starting from "*L"$|\downarrow \downarrow \rangle $, stde")
legend()

# pygui(true); show()
pygui(false);

# %% [markdown]
# # Convert to photon/$m^2$

# %%
L_list = (N ./ n_list).^(1/3)
S_list = 6*(L_list .*λ).^2;

Itot *= γ
I_SE_SR_SS *= γ
I_SR_SR_SS *= γ

Itot_per_stripe = Itot * (1 ./ S_list)
I_SE_SR_SS_per_stripe = I_SE_SR_SS * (1 ./ S_list)
I_SR_SR_SS_per_stripe = I_SR_SR_SS * (1 ./ S_list);

# %%
close("all")
fig = subplots()

plot(sat, I_SE_SR_SS_per_stripe, label="SE from SR SS")
plot(sat, I_SR_SR_SS_per_stripe, label="Collective decay from SR SS")
plot(sat, Itot_per_stripe, label="Sum of the decays")

xlabel(L"s")
ylabel(L"$I$")

suptitle("Starting from "*L"$|\downarrow \downarrow \rangle $, stde")
legend()

# pygui(true); show()
pygui(false);

# %%
if !isdir("Itot")
    mkdir("Itot")
end
@save "Itot/Itot_N_$(N)_Sat_$(sat[1])_to_$(sat[end])_decay_rate_up_down.jdl2" sat n_list Itot_per_stripe I_SE_SR_SS_per_stripe I_SR_SR_SS_per_stripe nbr_error_N
